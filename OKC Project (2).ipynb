# %% [markdown]
# # Let's find a data set:
#
# ### 60000 online dating profiles
#
# ### [Published](http://ww2.amstat.org/publications/jse/v23n2/kim.pdf) in the [Journal of Statistics Education](http://ww2.amstat.org/publications/jse/), Volume 23, Number 2 (2015) by Albert Y. Kim et al.
#
# ### CFAA: Explicitly allowed by OkCupid co-founder and CEO [Christian Rudder](http://blog.okcupid.com/)
#
# ### Ethically and legally acceptable
#
# ### [Wired article about ethical issues](https://www.wired.com/2016/05/okcupid-study-reveals-perils-big-data-science/))

# %% [markdown]
# ## Go to https://github.com/rudeboybert/JSE_OkCupid/raw/master/profiles_revised.csv.zip
# ## Click on the download button on the right side of the page
# ## upload that file into jupyter notebooks

# %%
# !unzip profiles_revised.csv.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as sm
import scipy.stats as stats

from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.cluster import KMeans

# %%
#import data

df = pd.read_csv("profiles_revised.csv")

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   ethnicity    54266 non-null  object
#  7   height       59943 non-null  float64
#  8   income       59946 non-null  int64
#  9   job          51748 non-null  object
#  10  offspring    24385 non-null  object
#  11  orientation  59946 non-null  object
#  12  pets         40025 non-null  object
#  13  religion     39720 non-null  object
#  14  sex          59946 non-null  object
#  15  sign         48890 non-null  object
#  16  smokes       54434 non-null  object
#  17  speaks       59896 non-null  object
#  18  status       59946 non-null  object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 8.7+ MB

# %%
df.describe()

#why are income percentiles = -1??
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.335402     68.295281    20033.222534
# std        9.490009      3.994803    97346.192104
# min       17.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      111.000000     95.000000  1000000.000000

# %%
#check for missing data

df.isnull().sum()

#people don't want to share about diet, kids, pets, or religion!
# Out:
# age                0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# offspring      35561
# orientation        0
# pets           19921
# religion       20226
# sex                0
# sign           11056
# smokes          5512
# speaks            50
# status             0
# dtype: int64

# %% [markdown]
# # Removing numerical outliers

# %% [markdown]
# ### Age

# %%
df2 = df.copy()

# %%
#check for outliers in numerical data

# 1. age

# creating new column with z-scores
df2["zscoreage"] = np.abs(stats.zscore(df2["age"]))

# identifying outliers with z-scores > 3
outlierAge = df2.loc[df2["zscoreage"]>3].index

print(outlierAge)

# many outliers in age category - let's see what the ages are
# Out:
# Int64Index([  172,   233,   257,   320,   323,   328,   335,   348,   349,
#               555,
#             ...
#             59186, 59283, 59303, 59326, 59428, 59501, 59534, 59601, 59740,
#             59837],
#            dtype='int64', length=981)

# %%
df2.loc[df2["zscoreage"]>3]

#outliers appear to be over 60 years old
# Out:
#        age       body_type               diet      drinks      drugs  \
# 172     62             fit           anything    socially      never
# 233     66             fit    mostly anything    socially      never
# 257     62            thin                NaN    socially      never
# 320     62  a little extra                NaN    socially  sometimes
# 323     61            thin           anything    socially      never
# ...    ...             ...                ...         ...        ...
# 59501   62           curvy           anything    socially      never
# 59534   61        athletic    mostly anything    socially      never
# 59601   70        athletic  mostly vegetarian  not at all  sometimes
# 59740   61        athletic           anything       often      never
# 59837   67           curvy           anything       often        NaN
#
#                                education ethnicity  height  income  \
# 172       graduated from masters program     white    73.0      -1
# 233    graduated from college/university     white    65.0   40000
# 257                      masters program     white    67.0      -1
# 320       graduated from masters program     white    67.0      -1
# 323    graduated from college/university     white    64.0      -1
# ...                                  ...       ...     ...     ...
# 59501     graduated from masters program     white    64.0      -1
# 59534     graduated from masters program     white    71.0  250000
# 59601    graduated from two-year college     white    63.0      -1
# 59740     graduated from masters program     white    73.0      -1
# 59837  graduated from college/university     white    62.0      -1
#
#                                      job                offspring orientation  \
# 172               executive / management                 has kids    straight
# 233                              retired                      NaN    straight
# 257          sales / marketing / biz dev                 has kids    straight
# 320                 education / academia  doesn&rsquo;t want kids         gay
# 323          artistic / musical / writer  doesn&rsquo;t have kids    straight
# ...                                  ...                      ...         ...
# 59501  banking / financial / real estate  doesn&rsquo;t have kids    straight
# 59534       science / tech / engineering                 has kids    straight
# 59601                  medicine / health                has a kid    straight
# 59740        artistic / musical / writer                 has kids    straight
# 59837        sales / marketing / biz dev                      NaN    straight
#
#                             pets                            religion sex  \
# 172                   likes dogs                        christianity   m
# 233    likes dogs and likes cats  christianity and laughing about it   f
# 257                          NaN                                 NaN   f
# 320                     has cats                                 NaN   f
# 323                     has dogs                               other   f
# ...                          ...                                 ...  ..
# 59501                        NaN                               other   f
# 59534  likes dogs and likes cats                                 NaN   m
# 59601                   has dogs         other and laughing about it   f
# 59740                   has cats   agnosticism and laughing about it   f
# 59837                        NaN  other but not too serious about it   f
#
#                                            sign          smokes  \
# 172                                         NaN              no
# 233    pisces and it&rsquo;s fun to think about              no
# 257                                         NaN             NaN
# 320    pisces and it&rsquo;s fun to think about              no
# 323                                         NaN              no
# ...                                         ...             ...
# 59501                                 capricorn              no
# 59534         aries but it doesn&rsquo;t matter              no
# 59601        gemini but it doesn&rsquo;t matter              no
# 59740        cancer but it doesn&rsquo;t matter  trying to quit
# 59837   aries and it&rsquo;s fun to think about              no
#
#                                        speaks  status  zscoreage
# 172                                   english  single   3.125903
# 233         english, french, spanish (poorly)  single   3.547402
# 257                                   english  single   3.125903
# 320                                   english  single   3.125903
# 323                                   english  single   3.020528
# ...                                       ...     ...        ...
# 59501                                 english  single   3.125903
# 59534                                 english  single   3.020528
# 59601                      english (fluently)  single   3.968902
# 59740  english (fluently), spanish (fluently)  single   3.020528
# 59837                                 english  single   3.652777
#
# [981 rows x 20 columns]

# %%
df2 = df2.drop(outlierAge)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58965 entries, 0 to 59945
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          58965 non-null  int64
#  1   body_type    53712 non-null  object
#  2   diet         34982 non-null  object
#  3   drinks       56011 non-null  object
#  4   drugs        44981 non-null  object
#  5   education    52434 non-null  object
#  6   ethnicity    53345 non-null  object
#  7   height       58962 non-null  float64
#  8   income       58965 non-null  int64
#  9   job          50859 non-null  object
#  10  offspring    23698 non-null  object
#  11  orientation  58965 non-null  object
#  12  pets         39344 non-null  object
#  13  religion     38921 non-null  object
#  14  sex          58965 non-null  object
#  15  sign         48103 non-null  object
#  16  smokes       53487 non-null  object
#  17  speaks       58916 non-null  object
#  18  status       58965 non-null  object
#  19  zscoreage    58965 non-null  float64
# dtypes: float64(2), int64(2), object(16)
# memory usage: 9.4+ MB

# %%
(df2["age"]<18).value_counts()

# 94 people listed under age 18 - REMOVE
# Out:
# False    58871
# True        94
# Name: age, dtype: int64

# %%
under_age = df2.loc[df2["age"]<18].index

# %%
df2 = df2.drop(under_age)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58871 entries, 0 to 59945
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          58871 non-null  int64
#  1   body_type    53624 non-null  object
#  2   diet         34924 non-null  object
#  3   drinks       55928 non-null  object
#  4   drugs        44896 non-null  object
#  5   education    52359 non-null  object
#  6   ethnicity    53261 non-null  object
#  7   height       58868 non-null  float64
#  8   income       58871 non-null  int64
#  9   job          50786 non-null  object
#  10  offspring    23644 non-null  object
#  11  orientation  58871 non-null  object
#  12  pets         39282 non-null  object
#  13  religion     38862 non-null  object
#  14  sex          58871 non-null  object
#  15  sign         48023 non-null  object
#  16  smokes       53404 non-null  object
#  17  speaks       58822 non-null  object
#  18  status       58871 non-null  object
#  19  zscoreage    58871 non-null  float64
# dtypes: float64(2), int64(2), object(16)
# memory usage: 9.4+ MB

# %%
#check to make sure under 18 removed

(df2["age"]>=18).value_counts()
# Out:
# True    58871
# Name: age, dtype: int64

# %% [markdown]
# ### Height

# %%
#check for outliers in numerical data

# 2. height

# creating new column with z-scores
df2["zscorehgt"] = np.abs(stats.zscore(df2["height"]))

# identifying outliers with z-scores > 3
outlierHgt = df2.loc[df2["zscorehgt"]>3].index

print(outlierHgt)

# no height outliers!
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ### Income

# %%
#check for outliers in numerical data

# 3. income

# creating new column with z-scores
df2["zscoreinc"] = np.abs(stats.zscore(df2["income"]))

# identifying outliers with z-scores > 3
outlierInc = df2.loc[df2["zscoreinc"]>3].index

print(outlierInc)

# many income outliers!
# Out:
# Int64Index([   48,   102,   107,   123,   216,   301,   697,   831,   937,
#               942,
#             ...
#             58834, 58908, 58927, 58981, 59099, 59280, 59429, 59551, 59818,
#             59855],
#            dtype='int64', length=567)

# %%
df2 = df2.drop(outlierInc)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...                       pets  \
# 0               transportation  ...  likes dogs and likes cats
# 1         hospitality / travel  ...  likes dogs and likes cats
# 2                          NaN  ...                   has cats
# 3                      student  ...                 likes cats
# 4  artistic / musical / writer  ...  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status zscoreage  \
# 0                                            english     single  1.089092
# 1  english (fluently), spanish (poorly), french (...     single  0.386157
# 2                               english, french, c++  available  0.491531
# 3                           english, german (poorly)     single  1.089092
# 4                                            english     single  0.246093
#
#   zscorehgt  zscoreinc
# 0       NaN   0.205508
# 1       NaN   0.611102
# 2       NaN   0.205508
# 3       NaN   0.001348
# 4       NaN   0.205508
#
# [5 rows x 22 columns]

# %%
#find number of rows with income = -1

fakeInc = df2.loc[df2["income"]==-1].index
print(fakeInc)

#income column appears to be a joke - drop it
# Out:
# Int64Index([    0,     2,     4,     5,     6,     7,     8,     9,    10,
#                12,
#             ...
#             59935, 59936, 59937, 59938, 59939, 59940, 59941, 59942, 59944,
#             59945],
#            dtype='int64', length=47576)

# %%
df2.loc[(df2["income"]==-1) & (df["body_type"] == "athletic")]

# income = -1 is non-response
# Out:
#        age body_type             diet      drinks  drugs  \
# 4       30  athletic              NaN    socially  never
# 9       37  athletic  mostly anything  not at all  never
# 19      34  athletic  mostly anything    socially  never
# 21      23  athletic              NaN    socially  never
# 31      28  athletic         anything    socially  never
# ...    ...       ...              ...         ...    ...
# 59868   31  athletic              NaN    socially    NaN
# 59880   24  athletic  mostly anything    socially  never
# 59919   41  athletic              NaN         NaN    NaN
# 59926   27  athletic  mostly anything    socially  never
# 59944   26  athletic  mostly anything    socially  often
#
#                                education            ethnicity  height  income  \
# 4      graduated from college/university  asian, black, other    66.0      -1
# 9            working on two-year college                white    65.0      -1
# 19        graduated from masters program                white    72.0      -1
# 21         working on college/university                  NaN    67.0      -1
# 31     graduated from college/university                  NaN    72.0      -1
# ...                                  ...                  ...     ...     ...
# 59868  graduated from college/university                black    70.0      -1
# 59880              working on med school                white    69.0      -1
# 59919  graduated from college/university                white    66.0      -1
# 59926         working on masters program                white    64.0      -1
# 59944      working on college/university         asian, black    73.0      -1
#
#                                 job  ...                       pets  \
# 4       artistic / musical / writer  ...  likes dogs and likes cats
# 9                           student  ...  likes dogs and likes cats
# 19     science / tech / engineering  ...  likes dogs and likes cats
# 21                          student  ...  likes dogs and likes cats
# 31     science / tech / engineering  ...                 likes dogs
# ...                             ...  ...                        ...
# 59868                         other  ...                        NaN
# 59880                       student  ...                 likes cats
# 59919   sales / marketing / biz dev  ...  likes dogs and likes cats
# 59926                           NaN  ...                 likes dogs
# 59944             medicine / health  ...  likes dogs and likes cats
#
#                                         religion sex  \
# 4                                            NaN   m
# 9                  atheism and laughing about it   m
# 19      catholicism but not too serious about it   m
# 21     catholicism and somewhat serious about it   f
# 31                                       atheism   m
# ...                                          ...  ..
# 59868                                        NaN   m
# 59880                                        NaN   m
# 59919         christianity and laughing about it   f
# 59926  christianity but not too serious about it   f
# 59944   agnosticism but not too serious about it   m
#
#                                               sign          smokes  \
# 4                                         aquarius              no
# 9               cancer but it doesn&rsquo;t matter              no
# 19        pisces and it&rsquo;s fun to think about              no
# 21              taurus but it doesn&rsquo;t matter              no
# 31                                             NaN              no
# ...                                            ...             ...
# 59868                                        aries             yes
# 59880          scorpio but it doesn&rsquo;t matter              no
# 59919  capricorn and it&rsquo;s fun to think about             NaN
# 59926                                          NaN              no
# 59944        leo and it&rsquo;s fun to think about  trying to quit
#
#                                                   speaks  status zscoreage  \
# 4                                                english  single  0.246093
# 9                                     english (fluently)  single  0.491531
# 19                                    english (fluently)  single  0.175407
# 21     english (fluently), spanish (fluently), italia...  single  0.983717
# 31                                               english  single  0.456842
# ...                                                  ...     ...       ...
# 59868                        english (fluently), spanish  single  0.140718
# 59880                                 english (fluently)  single  0.878342
# 59919               english (fluently), spanish (poorly)  single  0.913031
# 59926                                            english  single  0.562217
# 59944  english (fluently), spanish (poorly), chinese ...  single  0.667592
#
#       zscorehgt  zscoreinc
# 4           NaN   0.205508
# 9           NaN   0.205508
# 19          NaN   0.205508
# 21          NaN   0.205508
# 31          NaN   0.205508
# ...         ...        ...
# 59868       NaN   0.205508
# 59880       NaN   0.205508
# 59919       NaN   0.205508
# 59926       NaN   0.205508
# 59944       NaN   0.205508
#
# [9245 rows x 22 columns]

# %%
df2.isnull().sum()
# Out:
# age                0
# body_type       5216
# diet           23790
# drinks          2916
# drugs          13840
# education       6478
# ethnicity       5542
# height             3
# income             0
# job             8041
# offspring      34888
# orientation        0
# pets           19466
# religion       19881
# sex                0
# sign           10754
# smokes          5409
# speaks            49
# status             0
# zscoreage          0
# zscorehgt      58304
# zscoreinc          0
# dtype: int64

# %% [markdown]
# # Removing Columns with Too Much Missing Data
# - Income
# - Offspring

# %%
df2.drop(columns = ["zscoreage", "zscorehgt", "zscoreinc"], inplace = True)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58304 entries, 0 to 59945
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          58304 non-null  int64
#  1   body_type    53088 non-null  object
#  2   diet         34514 non-null  object
#  3   drinks       55388 non-null  object
#  4   drugs        44464 non-null  object
#  5   education    51826 non-null  object
#  6   ethnicity    52762 non-null  object
#  7   height       58301 non-null  float64
#  8   income       58304 non-null  int64
#  9   job          50263 non-null  object
#  10  offspring    23416 non-null  object
#  11  orientation  58304 non-null  object
#  12  pets         38838 non-null  object
#  13  religion     38423 non-null  object
#  14  sex          58304 non-null  object
#  15  sign         47550 non-null  object
#  16  smokes       52895 non-null  object
#  17  speaks       58255 non-null  object
#  18  status       58304 non-null  object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 10.9+ MB

# %% [markdown]
# # Feature Engineering

# %%
df2["drinks"].value_counts()
# Out:
# socially       40807
# rarely          5732
# often           5028
# not at all      3085
# very often       443
# desperately      293
# Name: drinks, dtype: int64

# %%
def drink_level(drink):
    if drink == "desperately":
        return 6
    if drink == "very often":
        return 5
    if drink == "often":
        return 4
    if drink == "socially":
        return 3
    if drink == "rarely":
        return 2
    if drink == "not at all":
        return 1

df2["drink_level"] = df2["drinks"].apply(drink_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0

# %%
df2["drugs"].value_counts()
# Out:
# never        36619
# sometimes     7476
# often          369
# Name: drugs, dtype: int64

# %%
def drugs_level(drug):
    if drug == "often":
        return 3
    if drug == "sometimes":
        return 2
    if drug == "never":
        return 1

df2["drugs_level"] = df2["drugs"].apply(drugs_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... orientation                       pets  \
# 0               transportation  ...    straight  likes dogs and likes cats
# 1         hospitality / travel  ...    straight  likes dogs and likes cats
# 2                          NaN  ...    straight                   has cats
# 3                      student  ...    straight                 likes cats
# 4  artistic / musical / writer  ...    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status drink_level  \
# 0                                            english     single         3.0
# 1  english (fluently), spanish (poorly), french (...     single         4.0
# 2                               english, french, c++  available         3.0
# 3                           english, german (poorly)     single         3.0
# 4                                            english     single         3.0
#
#    drugs_level
# 0          1.0
# 1          2.0
# 2          NaN
# 3          NaN
# 4          1.0
#
# [5 rows x 21 columns]

# %%
df2["education"].value_counts()
# Out:
# graduated from college/university    23466
# graduated from masters program        8646
# working on college/university         5598
# working on masters program            1666
# graduated from two-year college       1479
# graduated from high school            1375
# graduated from ph.d program           1196
# graduated from law school             1079
# working on two-year college           1055
# working on ph.d program                972
# dropped out of college/university      946
# college/university                     773
# graduated from space camp              605
# dropped out of space camp              485
# graduated from med school              430
# working on space camp                  418
# working on law school                  267
# working on med school                  209
# two-year college                       205
# dropped out of two-year college        178
# dropped out of masters program         133
# masters program                        129
# dropped out of ph.d program            119
# dropped out of high school              95
# high school                             92
# working on high school                  76
# space camp                              55
# ph.d program                            22
# law school                              19
# dropped out of law school               16
# dropped out of med school               11
# med school                              11
# Name: education, dtype: int64

# %%
# create 3 groups for Education Type

def edu_groups(type):
    if type == ("dropped out of high school" or "working on high school" or "high school"):
        return "HS or Less"
    if type == ("working on college/university" or "graduated from college/university" or "college/university" or "two-year college" or "graduated from two-year college" or "dropped out of college/university"):
        return "2-4-Year College"
    if type == ("graduated from masters program" or "working on masters program" or"graduated from ph.d program" or "graduated from law school" or "working on ph.d program" or "graduated from space camp" or "dropped out of space camp" or "graduated from med school" or "working on space camp" or "working on law school" or "working on med school" or "dropped out of masters program" or "masters program" or "dropped out of ph.d program" or "space camp" or "ph.d program" or "law school" or "dropped out of law school" or "dropped out of med school" or "med school"):
        return "More than College"

df2["Edu_Type"] = df2["education"].apply(edu_groups)

df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level           Edu_Type  Edu_Level  kids_level  dog_level  \
# 0          1.0   2-4-Year College          2         6.0        7.0
# 1          2.0               None          3         6.0        7.0
# 2          NaN  More than College          3         NaN        NaN
# 3          NaN   2-4-Year College          2         2.0        NaN
# 4          1.0               None          3         NaN        7.0
#
#    cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0          3.0             5   Omnivore
# 1        7.0          1.0             5      Other
# 2       10.0          1.0             4       None
# 3        6.0          1.0             5  Veg/Vegan
# 4        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level  height_level height_group
# 0           0.0           5.0     6' - 6'5
# 1           3.0           4.0   5'6 - 5'11
# 2           0.0           4.0   5'6 - 5'11
# 3           1.0           4.0   5'6 - 5'11
# 4           0.0           4.0   5'6 - 5'11

# %%
def edu_level(type):
    if type == "HS or Less":
        return 1
    if type == "2-4-Year College":
        return 2
    if type == "More than College":
        return 3

df2["Edu_Level"] = df2["Edu_Type"].apply(edu_level)

df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level           Edu_Type  Edu_Level  kids_level  dog_level  \
# 0          1.0   2-4-Year College        2.0         6.0        7.0
# 1          2.0               None        NaN         6.0        7.0
# 2          NaN  More than College        3.0         NaN        NaN
# 3          NaN   2-4-Year College        2.0         2.0        NaN
# 4          1.0               None        NaN         NaN        7.0
#
#    cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0          3.0             5   Omnivore
# 1        7.0          1.0             5      Other
# 2       10.0          1.0             4       None
# 3        6.0          1.0             5  Veg/Vegan
# 4        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level  height_level height_group
# 0           0.0           5.0     6' - 6'5
# 1           3.0           4.0   5'6 - 5'11
# 2           0.0           4.0   5'6 - 5'11
# 3           1.0           4.0   5'6 - 5'11
# 4           0.0           4.0   5'6 - 5'11

# %%
df2["offspring"].value_counts()
# Out:
# doesn&rsquo;t have kids                                7427
# doesn&rsquo;t have kids, but might want them           3819
# doesn&rsquo;t have kids, but wants them                3539
# doesn&rsquo;t want kids                                2779
# has a kid                                              1723
# has kids                                               1608
# doesn&rsquo;t have kids, and doesn&rsquo;t want any    1082
# has kids, but doesn&rsquo;t want more                   383
# has a kid, but doesn&rsquo;t want more                  234
# has a kid, and might want more                          228
# wants kids                                              220
# might want kids                                         177
# has kids, and might want more                           111
# has a kid, and wants more                                69
# has kids, and wants more                                 17
# Name: offspring, dtype: int64

# %%
def kids_level(ans):
    if ans == "has kids, and wants more":
        return 15
    if ans == "has a kid, and wants more":
        return 14
    if ans == "wants kids":
        return 13
    if ans == "doesn&rsquo;t have kids, but wants them":
        return 12
    if ans == "has kids, and might want more":
        return 11
    if ans == "has a kid, and might want more":
        return 10
    if ans == "has kids":
        return 9
    if ans == "has a kid":
        return 8
    if ans == "might want kids":
        return 7
    if ans == "doesn&rsquo;t have kids, but might want them":
        return 6
    if ans == "has kids, but doesn&rsquo;t want more":
        return 5
    if ans == "has a kid, but doesn&rsquo;t want more":
        return 4
    if ans == "doesn&rsquo;t have kids":
        return 3
    if ans == "doesn&rsquo;t want kids":
        return 2
    if ans == "doesn&rsquo;t have kids, and doesn&rsquo;t want any":
        return 1

df2["kids_level"] = df2["offspring"].apply(kids_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... sex                                sign  \
# 0               transportation  ...   m                              gemini
# 1         hospitality / travel  ...   m                              cancer
# 2                          NaN  ...   m  pisces but it doesn&rsquo;t matter
# 3                      student  ...   m                              pisces
# 4  artistic / musical / writer  ...   m                            aquarius
#
#       smokes                                             speaks     status  \
# 0  sometimes                                            english     single
# 1         no  english (fluently), spanish (poorly), french (...     single
# 2         no                               english, french, c++  available
# 3         no                           english, german (poorly)     single
# 4         no                                            english     single
#
#   drink_level drugs_level                        Edu_Type Edu_Level  \
# 0         3.0         1.0                2-4-Year College         2
# 1         4.0         2.0  Higher than College/University         3
# 2         3.0         NaN  Higher than College/University         3
# 3         3.0         NaN                2-4-Year College         2
# 4         3.0         1.0  Higher than College/University         3
#
#    kids_level
# 0         6.0
# 1         6.0
# 2         NaN
# 3         2.0
# 4         NaN
#
# [5 rows x 24 columns]

# %%
def pet_level(ans):
    if ans == "dislikes dogs and dislikes cats":
        return 1
    if ans == "dislikes dogs":
        return 1
    if ans == "dislikes cats":
        return 1
    if ans == "dislikes dogs and has cats":
        return 3
    if ans == "dislikes dogs and likes cats":
        return 2
    if ans == "likes dogs and has cats":
        return 5
    if ans == "likes dogs":
        return 4
    if ans == "likes cats":
        return 4
    if ans == "likes dogs and likes cats":
        return 3
    if ans == "has dogs and likes cats":
        return 5
    if ans == "has dogs and has cats":
        return 5
    if ans == "has dogs":
        return 5
    if ans =="likes dogs and dislikes cats":
        return 2
    if ans == "has dogs and dislikes cats":
        return 3

df2["pet_level"] = df2["pets"].apply(pet_level)

# %%
df2["pets"].value_counts()
# Out:
# likes dogs and likes cats          14374
# likes dogs                          7081
# likes dogs and has cats             4164
# has dogs                            4004
# has dogs and likes cats             2257
# likes dogs and dislikes cats        1989
# has dogs and has cats               1404
# has cats                            1345
# likes cats                          1035
# has dogs and dislikes cats           536
# dislikes dogs and likes cats         228
# dislikes dogs and dislikes cats      183
# dislikes cats                        117
# dislikes dogs and has cats            77
# dislikes dogs                         44
# Name: pets, dtype: int64

# %%
def dog_level(ans):
    if ans == "dislikes dogs and dislikes cats":
        return 1
    if ans == "dislikes dogs":
        return 2
    if ans == "dislikes dogs and has cats":
        return 3
    if ans == "dislikes dogs and likes cats":
        return 4
    if ans == "likes dogs and has cats":
        return 5
    if ans == "likes dogs":
        return 6
    if ans == "likes dogs and likes cats":
        return 7
    if ans == "has dogs and likes cats":
        return 8
    if ans == "has dogs and has cats":
        return 9
    if ans == "has dogs":
        return 10
    if ans =="likes dogs and dislikes cats":
        return 11
    if ans == "has dogs and dislikes cats":
        return 12

df2["dog_level"] = df2["pets"].apply(dog_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...                                sign  \
# 0               transportation  ...                              gemini
# 1         hospitality / travel  ...                              cancer
# 2                          NaN  ...  pisces but it doesn&rsquo;t matter
# 3                      student  ...                              pisces
# 4  artistic / musical / writer  ...                            aquarius
#
#       smokes                                             speaks     status  \
# 0  sometimes                                            english     single
# 1         no  english (fluently), spanish (poorly), french (...     single
# 2         no                               english, french, c++  available
# 3         no                           english, german (poorly)     single
# 4         no                                            english     single
#
#   drink_level drugs_level                        Edu_Type Edu_Level  \
# 0         3.0         1.0                2-4-Year College         2
# 1         4.0         2.0  Higher than College/University         3
# 2         3.0         NaN  Higher than College/University         3
# 3         3.0         NaN                2-4-Year College         2
# 4         3.0         1.0  Higher than College/University         3
#
#   kids_level  dog_level
# 0        6.0        7.0
# 1        6.0        7.0
# 2        NaN        NaN
# 3        2.0        NaN
# 4        NaN        7.0
#
# [5 rows x 25 columns]

# %%
df2["pets"].value_counts()
# Out:
# likes dogs and likes cats          14374
# likes dogs                          7081
# likes dogs and has cats             4164
# has dogs                            4004
# has dogs and likes cats             2257
# likes dogs and dislikes cats        1989
# has dogs and has cats               1404
# has cats                            1345
# likes cats                          1035
# has dogs and dislikes cats           536
# dislikes dogs and likes cats         228
# dislikes dogs and dislikes cats      183
# dislikes cats                        117
# dislikes dogs and has cats            77
# dislikes dogs                         44
# Name: pets, dtype: int64

# %%
def cat_level(ans):
    if ans == "dislikes dogs and dislikes cats":
        return 1
    if ans == "dislikes cats":
        return 2
    if ans == "has dogs and dislikes cats":
        return 3
    if ans == "likes dogs and dislikes cats":
        return 4
    if ans == "has dogs and likes cats":
        return 5
    if ans == "likes cats":
        return 6
    if ans == "likes dogs and likes cats":
        return 7
    if ans == "likes dogs and has cats":
        return 8
    if ans == "has dogs and has cats":
        return 9
    if ans == "has cats":
        return 10
    if ans =="dislikes dogs and likes cats":
        return 11
    if ans == "dislikes dogs and has cats":
        return 12

df2["cat_level"] = df2["pets"].apply(cat_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...     smokes  \
# 0               transportation  ...  sometimes
# 1         hospitality / travel  ...         no
# 2                          NaN  ...         no
# 3                      student  ...         no
# 4  artistic / musical / writer  ...         no
#
#                                               speaks     status drink_level  \
# 0                                            english     single         3.0
# 1  english (fluently), spanish (poorly), french (...     single         4.0
# 2                               english, french, c++  available         3.0
# 3                           english, german (poorly)     single         3.0
# 4                                            english     single         3.0
#
#   drugs_level                        Edu_Type Edu_Level kids_level dog_level  \
# 0         1.0                2-4-Year College         2        6.0       7.0
# 1         2.0  Higher than College/University         3        6.0       7.0
# 2         NaN  Higher than College/University         3        NaN       NaN
# 3         NaN                2-4-Year College         2        2.0       NaN
# 4         1.0  Higher than College/University         3        NaN       7.0
#
#    cat_level
# 0        7.0
# 1        7.0
# 2       10.0
# 3        6.0
# 4        7.0
#
# [5 rows x 26 columns]

# %%
df2["smokes"].value_counts()
# Out:
# no                42624
# sometimes          3676
# when drinking      2988
# yes                2169
# trying to quit     1438
# Name: smokes, dtype: int64

# %%
def smoke_level(ans):
    if ans == "no":
        return 1
    if ans == "when drinking":
        return 2
    if ans == "sometimes":
        return 3
    if ans == "trying to quit":
        return 4
    if ans == "yes":
        return 5

df2["smoke_level"] = df2["smokes"].apply(smoke_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...  \
# 0               transportation  ...
# 1         hospitality / travel  ...
# 2                          NaN  ...
# 3                      student  ...
# 4  artistic / musical / writer  ...
#
#                                               speaks     status drink_level  \
# 0                                            english     single         3.0
# 1  english (fluently), spanish (poorly), french (...     single         4.0
# 2                               english, french, c++  available         3.0
# 3                           english, german (poorly)     single         3.0
# 4                                            english     single         3.0
#
#   drugs_level                        Edu_Type Edu_Level kids_level dog_level  \
# 0         1.0                2-4-Year College         2        6.0       7.0
# 1         2.0  Higher than College/University         3        6.0       7.0
# 2         NaN  Higher than College/University         3        NaN       NaN
# 3         NaN                2-4-Year College         2        2.0       NaN
# 4         1.0  Higher than College/University         3        NaN       7.0
#
#   cat_level  smoke_level
# 0       7.0          3.0
# 1       7.0          1.0
# 2      10.0          1.0
# 3       6.0          1.0
# 4       7.0          1.0
#
# [5 rows x 27 columns]

# %%
df2["status"].value_counts()
# Out:
# single            54161
# seeing someone     2027
# available          1807
# married             299
# unknown              10
# Name: status, dtype: int64

# %%
def status_level(ans):
    if ans == "unknown":
        return 1
    if ans == "married":
        return 2
    if ans == "seeing someone":
        return 3
    if ans == "available":
        return 4
    if ans == "single":
        return 5

df2["status_level"] = df2["status"].apply(status_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...     status drink_level drugs_level  \
# 0               transportation  ...     single         3.0         1.0
# 1         hospitality / travel  ...     single         4.0         2.0
# 2                          NaN  ...  available         3.0         NaN
# 3                      student  ...     single         3.0         NaN
# 4  artistic / musical / writer  ...     single         3.0         1.0
#
#                          Edu_Type Edu_Level kids_level dog_level cat_level  \
# 0                2-4-Year College         2        6.0       7.0       7.0
# 1  Higher than College/University         3        6.0       7.0       7.0
# 2  Higher than College/University         3        NaN       NaN      10.0
# 3                2-4-Year College         2        2.0       NaN       6.0
# 4  Higher than College/University         3        NaN       7.0       7.0
#
#   smoke_level  status_level
# 0         3.0             5
# 1         1.0             5
# 2         1.0             4
# 3         1.0             5
# 4         1.0             5
#
# [5 rows x 28 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58304 entries, 0 to 59945
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           58304 non-null  int64
#  1   body_type     53088 non-null  object
#  2   diet          34514 non-null  object
#  3   drinks        55388 non-null  object
#  4   drugs         44464 non-null  object
#  5   education     51826 non-null  object
#  6   ethnicity     52762 non-null  object
#  7   height        58301 non-null  float64
#  8   income        58304 non-null  int64
#  9   job           50263 non-null  object
#  10  offspring     23416 non-null  object
#  11  orientation   58304 non-null  object
#  12  pets          38838 non-null  object
#  13  religion      38423 non-null  object
#  14  sex           58304 non-null  object
#  15  sign          47550 non-null  object
#  16  smokes        52895 non-null  object
#  17  speaks        58255 non-null  object
#  18  status        58304 non-null  object
#  19  drink_level   55388 non-null  float64
#  20  drugs_level   44464 non-null  float64
#  21  Edu_Type      58304 non-null  object
#  22  Edu_Level     58304 non-null  int64
#  23  kids_level    23416 non-null  float64
#  24  dog_level     36341 non-null  float64
#  25  cat_level     27709 non-null  float64
#  26  smoke_level   52895 non-null  float64
#  27  status_level  58304 non-null  int64
# dtypes: float64(7), int64(4), object(17)
# memory usage: 14.9+ MB

# %% [markdown]
# # Identifying and Grouping Types of Entries in Categorical Columns

# %%
df2["body_type"].value_counts()
# Out:
# average           14215
# fit               12361
# athletic          11573
# thin               4574
# curvy              3819
# a little extra     2505
# skinny             1745
# full figured        969
# overweight          430
# jacked              385
# used up             319
# rather not say      193
# Name: body_type, dtype: int64

# %%
# create 5 groups for body type

def body_groups(type):
    if type == ("thin" or "skinny"):
        return "Thin"
    if type == "average":
        return "Average"
    if type == ("a little extra" or "curvy" or "full figured" or "overweight"):
        return "Heavy"
    if type == ("athletic" or "jacked" or "fit"):
        return "Athletic"
    if type == ("rather not say" or "used up"):
        return "Other"

df["Body_Type"] = df["body_type"].apply(body_groups)

df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status Body_Type
# 0                                            english     single     Heavy
# 1  english (fluently), spanish (poorly), french (...     single   Average
# 2                               english, french, c++  available      Thin
# 3                           english, german (poorly)     single      Thin
# 4                                            english     single  Athletic

# %%
## histogram for Body Type

sns.histplot(x = df["Body_Type"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Body Types - Smaller Groupings")
# Out:
# Text(0.5, 1.0, 'Count of Body Types - Smaller Groupings')

# %%
df2["diet"].value_counts()
# Out:
# mostly anything        16168
# anything                6020
# strictly anything       4981
# mostly vegetarian       3295
# mostly other             953
# strictly vegetarian      852
# vegetarian               657
# strictly other           421
# mostly vegan             322
# other                    317
# strictly vegan           222
# vegan                    132
# mostly kosher             79
# mostly halal              45
# strictly halal            16
# strictly kosher           13
# kosher                    11
# halal                     10
# Name: diet, dtype: int64

# %%
# create 4 groups for Diet Type

def diet_groups(type):
    if type == ("vegetarian" or "mostly vegetarian" or "strictly vegan" or "strictly vegetarian" or "mostly vegan" or "vegan"):
        return "Veg/Vegan"
    if type == ("strictly anything" or "anything" or "mostly anything"):
        return "Omnivore"
    if type == ("mostly halal" or "mostly kosher" or "halal" or "strictly halal" or "kosher" or "strictly kosher"):
        return "Religion-based"
    if type == ("mostly other" or "strictly other" or "other"):
        return "Other"

df2["Diet_Type"] = df2["diet"].apply(diet_groups)

df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... drink_level drugs_level  \
# 0               transportation  ...         3.0         1.0
# 1         hospitality / travel  ...         4.0         2.0
# 2                          NaN  ...         3.0         NaN
# 3                      student  ...         3.0         NaN
# 4  artistic / musical / writer  ...         3.0         1.0
#
#                          Edu_Type Edu_Level kids_level dog_level cat_level  \
# 0                2-4-Year College         2        6.0       7.0       7.0
# 1  Higher than College/University         3        6.0       7.0       7.0
# 2  Higher than College/University         3        NaN       NaN      10.0
# 3                2-4-Year College         2        2.0       NaN       6.0
# 4  Higher than College/University         3        NaN       7.0       7.0
#
#   smoke_level status_level  Diet_Type
# 0         3.0            5   Omnivore
# 1         1.0            5      Other
# 2         1.0            4       None
# 3         1.0            5  Veg/Vegan
# 4         1.0            5       None
#
# [5 rows x 29 columns]

# %%
## histogram for diet

sns.histplot(x = df2["Diet_Type"], kde = False)
plt.xticks(rotation = 90)
plt.title('Count of Diet Types by Grouping')
# Out:
# Text(0.5, 1.0, 'Count of Diet Types by Grouping')

# %%
## histogram for drinks

sns.histplot(x = df["drinks"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drink Type")
# Out:
# Text(0.5, 1.0, 'Count of Drink Type')

# %%
## histogram for drink_level

sns.histplot(x = df2["drink_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drink Levels")
# Out:
# Text(0.5, 1.0, 'Count of Drink Levels')

# %%
## histogram for drugs

sns.histplot(x = df["drugs"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drugs Type")
# Out:
# Text(0.5, 1.0, 'Count of Drugs Type')

# %%
## histogram for drugs_level

sns.histplot(x = df2["drugs_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drugs Levels")
# Out:
# Text(0.5, 1.0, 'Count of Drugs Levels')

# %%
## histogram for education level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["Edu_Level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Education Level")
# Out:
# Text(0.5, 1.0, 'Count of Education Level')

# %%
## histogram for education type

plt.figure(figsize = (15,5))
sns.histplot(x = df2["Edu_Type"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Education Type")
# Out:
# Text(0.5, 1.0, 'Count of Education Type')

# %%
## histogram for sexual orientation

plt.figure(figsize = (15,5))
sns.histplot(x = df2["orientation"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Orientation")
# Out:
# Text(0.5, 1.0, 'Count of Orientation')

# %%
df2["religion"].value_counts()
# Out:
# agnosticism                                   2663
# agnosticism but not too serious about it      2579
# other                                         2563
# agnosticism and laughing about it             2428
# catholicism but not too serious about it      2278
# atheism                                       2123
# other and laughing about it                   2034
# atheism and laughing about it                 2018
# christianity                                  1915
# christianity but not too serious about it     1894
# other but not too serious about it            1477
# judaism but not too serious about it          1417
# atheism but not too serious about it          1298
# catholicism                                   1046
# christianity and somewhat serious about it     885
# atheism and somewhat serious about it          825
# other and somewhat serious about it            803
# catholicism and laughing about it              712
# judaism and laughing about it                  666
# buddhism but not too serious about it          634
# agnosticism and somewhat serious about it      625
# judaism                                        590
# christianity and very serious about it         556
# atheism and very serious about it              548
# catholicism and somewhat serious about it      537
# other and very serious about it                478
# buddhism and laughing about it                 437
# buddhism                                       389
# christianity and laughing about it             357
# buddhism and somewhat serious about it         335
# agnosticism and very serious about it          300
# judaism and somewhat serious about it          250
# hinduism but not too serious about it          224
# hinduism                                       106
# catholicism and very serious about it           96
# buddhism and very serious about it              65
# hinduism and somewhat serious about it          57
# islam                                           47
# hinduism and laughing about it                  44
# islam but not too serious about it              39
# islam and somewhat serious about it             22
# judaism and very serious about it               21
# islam and laughing about it                     16
# hinduism and very serious about it              13
# islam and very serious about it                 13
# Name: religion, dtype: int64

# %%
def rel_level_2(ans):
    if ans == "hinduism and laughing about it":
        return 1
    if ans == "islam and laughing about it":
        return 1
    if ans == "buddhism and laughing about it":
        return 1
    if ans == "judaism and laughing about it":
        return 1
    if ans == "christianity and laughing about it":
        return 1
    if ans == "catholicism and laughing about it":
        return 1
    if ans == "hinduism but not too serious about it":
        return 2
    if ans == "islam but not too serious about it":
        return 2
    if ans == "buddhism but not too serious about it":
        return 2
    if ans == "judaism but not too serious about it":
        return 2
    if ans == "christianity but not too serious about it":
        return 2
    if ans == "catholicism but not too serious about it":
        return 2
    if ans == "hinduism":
        return 3
    if ans == "islam":
        return 3
    if ans == "buddhism":
        return 3
    if ans == "judaism":
        return 3
    if ans == "christianity":
        return 3
    if ans == "catholicism":
        return 3
    if ans == "hinduism and somewhat serious about it":
        return 4
    if ans == "islam and somewhat serious about it":
        return 4
    if ans == "buddhism and somewhat serious about it":
        return 4
    if ans == "judaism and somewhat serious about it":
        return 4
    if ans == "christianity and somewhat serious about it":
        return 4
    if ans == "catholicism and somewhat serious about it":
        return 4
    if ans == "hinduism and very serious about it":
        return 5 
    if ans == "islam and very serious about it":
        return 5 
    if ans == "buddhism and very serious about it":
        return 5 
    if ans == "judaism and very serious about it":
        return 5 
    if ans == "christianity and very serious about it":
        return 5 
    if ans == "catholicism and very serious about it":
        return 5 
    
df2["religious_level_no_ath_agn"] = df2["religion"].apply(rel_level_2)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... drugs_level  \
# 0               transportation  ...         1.0
# 1         hospitality / travel  ...         2.0
# 2                          NaN  ...         NaN
# 3                      student  ...         NaN
# 4  artistic / musical / writer  ...         1.0
#
#                          Edu_Type Edu_Level kids_level dog_level cat_level  \
# 0                2-4-Year College         2        6.0       7.0       7.0
# 1  Higher than College/University         3        6.0       7.0       7.0
# 2  Higher than College/University         3        NaN       NaN      10.0
# 3                2-4-Year College         2        2.0       NaN       6.0
# 4  Higher than College/University         3        NaN       7.0       7.0
#
#   smoke_level status_level  Diet_Type  religious_level_no_ath_agn
# 0         3.0            5   Omnivore                         NaN
# 1         1.0            5      Other                         NaN
# 2         1.0            4       None                         NaN
# 3         1.0            5  Veg/Vegan                         NaN
# 4         1.0            5       None                         NaN
#
# [5 rows x 30 columns]

# %%
## histogram for religious level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["religious_level_no_ath_agn"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Religious Levels (without Atheism or Agnosticism)")
# Out:
# Text(0.5, 1.0, 'Count of Religious Levels (without Atheism or Agnosticism)')

# %%
# EASIER, FASTER ALTERNATIVE TO CREATING RELIGION STRENGTH AND GROUPS

#def evalReligion(txt):
    #rel = ''
    #relstrength = -1
    #if "christianity" in txt:
        #rel = "Christianity"
    #elif "Judaism" in txt:
        #rel = "Judaism"
    #elif 
    
    #if "and serious about it" in txt:
        #relstrength = 5
    #elif "serious about it" in txt:
        #relstrength = 4
        
    #return rel, relstrength

#religion, religionstrength = evalReligion("christianity and not serious about it")

# %%
df2.describe()
# Out:
#                 age        height         income   drink_level   drugs_level  \
# count  58304.000000  58301.000000   58304.000000  55388.000000  44464.000000
# mean      31.857883     68.298914   11014.551729      2.907760      1.184734
# std        8.621917      3.969843   29519.631561      0.698685      0.408912
# min       18.000000      1.000000      -1.000000      1.000000      1.000000
# 25%       26.000000     66.000000      -1.000000      3.000000      1.000000
# 50%       30.000000     68.000000      -1.000000      3.000000      1.000000
# 75%       36.000000     71.000000      -1.000000      3.000000      1.000000
# max       60.000000     95.000000  250000.000000      6.000000      3.000000
#
#           Edu_Level    kids_level     dog_level     cat_level   smoke_level  \
# count  58304.000000  23416.000000  36341.000000  27709.000000  52895.000000
# mean       2.900727      5.732448      7.275006      6.890324      1.441062
# std        0.304431      3.638248      1.825442      1.625125      1.020158
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      3.000000      6.000000      7.000000      1.000000
# 50%        3.000000      5.000000      7.000000      7.000000      1.000000
# 75%        3.000000      8.000000      8.000000      8.000000      1.000000
# max        3.000000     15.000000     12.000000     12.000000      5.000000
#
#        status_level  religious_level_no_ath_agn  religious_level  \
# count  58304.000000                15661.000000     15661.000000
# mean       4.883404                    2.531575         2.531575
# std        0.453172                    1.045566         1.045566
# min        1.000000                    1.000000         1.000000
# 25%        5.000000                    2.000000         2.000000
# 50%        5.000000                    2.000000         2.000000
# 75%        5.000000                    3.000000         3.000000
# max        5.000000                    5.000000         5.000000
#
#        agnosticism_level  atheism_level  hinduism_level  islam_level  \
# count        8595.000000    6812.000000      444.000000   137.000000
# mean            2.277487       2.498972        2.484234     2.832117
# std             1.058516       1.252042        0.939345     1.128308
# min             1.000000       1.000000        1.000000     1.000000
# 25%             1.000000       1.000000        2.000000     2.000000
# 50%             2.000000       3.000000        2.000000     3.000000
# 75%             3.000000       3.000000        3.000000     4.000000
# max             5.000000       5.000000        5.000000     5.000000
#
#        buddhism_level  judaism_level  christianity_level  catholicism_level  \
# count     1860.000000    2944.000000         5607.000000        4669.000000
# mean         2.439247       2.165421            2.891029           2.363247
# std          1.134366       0.896332            1.065498           0.943331
# min          1.000000       1.000000            1.000000           1.000000
# 25%          2.000000       2.000000            2.000000           2.000000
# 50%          2.000000       2.000000            3.000000           2.000000
# 75%          3.000000       3.000000            4.000000           3.000000
# max          5.000000       5.000000            5.000000           5.000000
#
#        income_level
# count  53144.000000
# mean       0.198179
# std        0.675328
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        4.000000

# %%
def hgt_group(ans):
    if ans < 48:
        return "less than 4'"
    if (ans >= 48 and ans < 60):
        return "4' - 4'11"
    if (ans >= 60 and ans <66):
        return "5' - 5'5"
    if (ans >= 66 and ans <72):
        return "5'6 - 5'11"
    if (ans >= 72 and ans <78):
        return "6' - 6'5"
    if (ans >78):
        return "6'6+"

df2["height_group"] = df2["height"].apply(hgt_group)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level                        Edu_Type  Edu_Level  kids_level  \
# 0          1.0                2-4-Year College          2         6.0
# 1          2.0  Higher than College/University          3         6.0
# 2          NaN  Higher than College/University          3         NaN
# 3          NaN                2-4-Year College          2         2.0
# 4          1.0  Higher than College/University          3         NaN
#
#    dog_level  cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0        7.0          3.0             5   Omnivore
# 1        7.0        7.0          1.0             5      Other
# 2        NaN       10.0          1.0             4       None
# 3        NaN        6.0          1.0             5  Veg/Vegan
# 4        7.0        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level height_level height_group
# 0           0.0     6' - 6'5     6' - 6'5
# 1           3.0   5'6 - 5'11   5'6 - 5'11
# 2           0.0   5'6 - 5'11   5'6 - 5'11
# 3           1.0   5'6 - 5'11   5'6 - 5'11
# 4           0.0   5'6 - 5'11   5'6 - 5'11

# %%
def hgt_level(ans):
    if ans < 48:
        return 1
    if (ans >= 48 and ans < 60):
        return 2
    if (ans >= 60 and ans <66):
        return 3
    if (ans >= 66 and ans <72):
        return 4
    if (ans >= 72 and ans <78):
        return 5
    if (ans >78):
        return 6

df2["height_level"] = df2["height"].apply(hgt_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level                        Edu_Type  Edu_Level  kids_level  \
# 0          1.0                2-4-Year College          2         6.0
# 1          2.0  Higher than College/University          3         6.0
# 2          NaN  Higher than College/University          3         NaN
# 3          NaN                2-4-Year College          2         2.0
# 4          1.0  Higher than College/University          3         NaN
#
#    dog_level  cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0        7.0          3.0             5   Omnivore
# 1        7.0        7.0          1.0             5      Other
# 2        NaN       10.0          1.0             4       None
# 3        NaN        6.0          1.0             5  Veg/Vegan
# 4        7.0        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level  height_level height_group
# 0           0.0           5.0     6' - 6'5
# 1           3.0           4.0   5'6 - 5'11
# 2           0.0           4.0   5'6 - 5'11
# 3           1.0           4.0   5'6 - 5'11
# 4           0.0           4.0   5'6 - 5'11

# %%
df2["income"].value_counts()
# Out:
# -1         47576
#  20000      2919
#  100000     1586
#  80000      1081
#  30000      1031
#  40000       985
#  50000       951
#  60000       717
#  70000       694
#  150000      617
#  250000      147
# Name: income, dtype: int64

# %%
def inc_group(ans):
    if ans == -1:
        return "Unknown"
    if ans == (20000 or 30000 or 40000):
        return "$20K-$49K"
    if ans == (50000 or 60000 or 70000):
        return "$50K-$79K"
    if ans == (80000 or 100000):
        return "$80K-$149K"
    if ans == (150000 or 250000):
        return "$150K+"
    
df2["income_group"] = df2["income"].apply(inc_group)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level                        Edu_Type  Edu_Level  kids_level  \
# 0          1.0                2-4-Year College          2         6.0
# 1          2.0  Higher than College/University          3         6.0
# 2          NaN  Higher than College/University          3         NaN
# 3          NaN                2-4-Year College          2         2.0
# 4          1.0  Higher than College/University          3         NaN
#
#    dog_level  cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0        7.0          3.0             5   Omnivore
# 1        7.0        7.0          1.0             5      Other
# 2        NaN       10.0          1.0             4       None
# 3        NaN        6.0          1.0             5  Veg/Vegan
# 4        7.0        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level
# 0           0.0
# 1           3.0
# 2           0.0
# 3           1.0
# 4           0.0

# %%
## histogram for income group

plt.figure(figsize = (15,5))
sns.histplot(x = df2["income_group"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Income Groups")
# Out:
# Text(0.5, 1.0, 'Count of Income Groups')

# %%
def inc_level(ans):
    if ans == "$20K-$49K":
        return 1
    if ans == "$50K-$79K":
        return 2
    if ans == "$80K-$149K":
        return 3
    if ans == "$150K+":
        return 4    

df2["income_level"] = df2["income_group"].apply(inc_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level           Edu_Type  Edu_Level  kids_level  dog_level  \
# 0          1.0   2-4-Year College        2.0         6.0        7.0
# 1          2.0               None        NaN         6.0        7.0
# 2          NaN  More than College        3.0         NaN        NaN
# 3          NaN   2-4-Year College        2.0         2.0        NaN
# 4          1.0               None        NaN         NaN        7.0
#
#    cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0          3.0             5   Omnivore
# 1        7.0          1.0             5      Other
# 2       10.0          1.0             4       None
# 3        6.0          1.0             5  Veg/Vegan
# 4        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group income_group  \
# 0                 NaN                NaN       Agnostic      Unknown
# 1                 NaN                NaN       Agnostic   $80K-$149K
# 2                 NaN                NaN           None      Unknown
# 3                 NaN                NaN           None    $20K-$49K
# 4                 NaN                NaN           None      Unknown
#
#    income_level  height_level height_group
# 0           NaN           5.0     6' - 6'5
# 1           3.0           4.0   5'6 - 5'11
# 2           NaN           4.0   5'6 - 5'11
# 3           1.0           4.0   5'6 - 5'11
# 4           NaN           4.0   5'6 - 5'11

# %%
## histogram for income level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["income_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Income Levels")
# Out:
# Text(0.5, 1.0, 'Count of Income Levels')

# %%
def rel_level(ans):
    if ans == "agnosticism and laughing about it":
        return 1
    if ans == "agnosticism but not too serious about it":
        return 1
    if ans == "agnosticism":
        return 1
    if ans == "agnosticism and somewhat serious about it":
        return 1
    if ans == "agnosticism and very serious about it":
        return 1
    if ans == "atheism and laughing about it":
        return 1
    if ans == "atheism but not too serious about it":
        return 1
    if ans == "atheism":
        return 1
    if ans == "atheism and somewhat serious about it":
        return 1
    if ans == "atheism and very serious about it":
        return 1
    if ans == "hinduism and laughing about it":
        return 1
    if ans == "islam and laughing about it":
        return 1
    if ans == "buddhism and laughing about it":
        return 1
    if ans == "judaism and laughing about it":
        return 1
    if ans == "christianity and laughing about it":
        return 1
    if ans == "catholicism and laughing about it":
        return 1
    if ans == "hinduism but not too serious about it":
        return 2
    if ans == "islam but not too serious about it":
        return 2
    if ans == "buddhism but not too serious about it":
        return 2
    if ans == "judaism but not too serious about it":
        return 2
    if ans == "christianity but not too serious about it":
        return 2
    if ans == "catholicism but not too serious about it":
        return 2
    if ans == "hinduism":
        return 3
    if ans == "islam":
        return 3
    if ans == "buddhism":
        return 3
    if ans == "judaism":
        return 3
    if ans == "christianity":
        return 3
    if ans == "catholicism":
        return 3
    if ans == "hinduism and somewhat serious about it":
        return 4
    if ans == "islam and somewhat serious about it":
        return 4
    if ans == "buddhism and somewhat serious about it":
        return 4
    if ans == "judaism and somewhat serious about it":
        return 4
    if ans == "christianity and somewhat serious about it":
        return 4
    if ans == "catholicism and somewhat serious about it":
        return 4
    if ans == "hinduism and very serious about it":
        return 5 
    if ans == "islam and very serious about it":
        return 5 
    if ans == "buddhism and very serious about it":
        return 5 
    if ans == "judaism and very serious about it":
        return 5 
    if ans == "christianity and very serious about it":
        return 5 
    if ans == "catholicism and very serious about it":
        return 5 
    
df2["religious_level"] = df2["religion"].apply(rel_level_2)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...                        Edu_Type Edu_Level  \
# 0               transportation  ...                2-4-Year College         2
# 1         hospitality / travel  ...  Higher than College/University         3
# 2                          NaN  ...  Higher than College/University         3
# 3                      student  ...                2-4-Year College         2
# 4  artistic / musical / writer  ...  Higher than College/University         3
#
#   kids_level dog_level cat_level smoke_level status_level  Diet_Type  \
# 0        6.0       7.0       7.0         3.0            5   Omnivore
# 1        6.0       7.0       7.0         1.0            5      Other
# 2        NaN       NaN      10.0         1.0            4       None
# 3        2.0       NaN       6.0         1.0            5  Veg/Vegan
# 4        NaN       7.0       7.0         1.0            5       None
#
#   religious_level_no_ath_agn  religious_level
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
#
# [5 rows x 31 columns]

# %%
## histogram for religious level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["religious_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Religious Levels")
# Out:
# Text(0.5, 1.0, 'Count of Religious Levels')

# %%
def rel_group(ans):
    if ans == "judaism and laughing about it":
        return "Jewish"
    if ans == "judaism but not too serious about it":
        return "Jewish"
    if ans == "judaism":
        return "Jewish"
    if ans == "judaism and somewhat serious about it":
        return "Jewish"
    if ans == "judaism and very serious about it":
        return "Jewish" 
    if ans == "catholicism and laughing about it":
        return "Catholic"
    if ans == "catholicism but not too serious about it":
        return "Catholic"
    if ans == "catholicism":
        return "Catholic"
    if ans == "catholicism and somewhat serious about it":
        return "Catholic"
    if ans == "catholicism and very serious about it":
        return "Catholic" 
    if ans == "christianity and laughing about it":
        return "Christian"
    if ans == "christianity but not too serious about it":
        return "Christian"
    if ans == "christianity":
        return "Christian"
    if ans == "christianity and somewhat serious about it":
        return "Christian"
    if ans == "christianity and very serious about it":
        return "Christian"
    if ans == "hinduism and laughing about it":
        return "Hindu"
    if ans == "hinduism but not too serious about it":
        return "Hindu"
    if ans == "hinduism":
        return "Hindu"
    if ans == "hinduism and somewhat serious about it":
        return "Hindu"
    if ans == "hinduism and very serious about it":
        return "Hindu" 
    if ans == "buddhism and laughing about it":
        return "Buddhist"
    if ans == "buddhism but not too serious about it":
        return "Buddhist"
    if ans == "buddhism":
        return "Buddhist"
    if ans == "buddhism and somewhat serious about it":
        return "Buddhist"
    if ans == "buddhism and very serious about it":
        return "Buddhist" 
    if ans == "agnosticism and laughing about it":
        return "Agnostic"
    if ans == "agnosticism but not too serious about it":
        return "Agnostic"
    if ans == "agnosticism":
        return "Agnostic"
    if ans == "agnosticism and somewhat serious about it":
        return "Agnostic"
    if ans == "agnosticism and very serious about it":
        return "Agnostic"
    if ans == "atheism and laughing about it":
        return "Atheist"
    if ans == "atheism but not too serious about it":
        return "Atheist"
    if ans == "atheism":
        return "Atheist"
    if ans == "atheism and somewhat serious about it":
        return "Atheist"
    if ans == "atheism and very serious about it":
        return "Atheist"

df2["religion_group"] = df2["religion"].apply(rel_group)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job                                     offspring  \
# 0               transportation  doesn&rsquo;t have kids, but might want them
# 1         hospitality / travel  doesn&rsquo;t have kids, but might want them
# 2                          NaN                                           NaN
# 3                      student                       doesn&rsquo;t want kids
# 4  artistic / musical / writer                                           NaN
#
#   orientation                       pets  \
# 0    straight  likes dogs and likes cats
# 1    straight  likes dogs and likes cats
# 2    straight                   has cats
# 3    straight                 likes cats
# 4    straight  likes dogs and likes cats
#
#                                    religion sex  \
# 0     agnosticism and very serious about it   m
# 1  agnosticism but not too serious about it   m
# 2                                       NaN   m
# 3                                       NaN   m
# 4                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status  drink_level  \
# 0                                            english     single          3.0
# 1  english (fluently), spanish (poorly), french (...     single          4.0
# 2                               english, french, c++  available          3.0
# 3                           english, german (poorly)     single          3.0
# 4                                            english     single          3.0
#
#    drugs_level                        Edu_Type  Edu_Level  kids_level  \
# 0          1.0                2-4-Year College          2         6.0
# 1          2.0  Higher than College/University          3         6.0
# 2          NaN  Higher than College/University          3         NaN
# 3          NaN                2-4-Year College          2         2.0
# 4          1.0  Higher than College/University          3         NaN
#
#    dog_level  cat_level  smoke_level  status_level  Diet_Type  \
# 0        7.0        7.0          3.0             5   Omnivore
# 1        7.0        7.0          1.0             5      Other
# 2        NaN       10.0          1.0             4       None
# 3        NaN        6.0          1.0             5  Veg/Vegan
# 4        7.0        7.0          1.0             5       None
#
#    religious_level_no_ath_agn  religious_level  agnosticism_level  \
# 0                         NaN              NaN                5.0
# 1                         NaN              NaN                2.0
# 2                         NaN              NaN                NaN
# 3                         NaN              NaN                NaN
# 4                         NaN              NaN                NaN
#
#    atheism_level  hinduism_level  islam_level  buddhism_level  judaism_level  \
# 0            NaN             NaN          NaN             NaN            NaN
# 1            NaN             NaN          NaN             NaN            NaN
# 2            NaN             NaN          NaN             NaN            NaN
# 3            NaN             NaN          NaN             NaN            NaN
# 4            NaN             NaN          NaN             NaN            NaN
#
#    christianity_level  catholicism_level religion_group
# 0                 NaN                NaN       Agnostic
# 1                 NaN                NaN       Agnostic
# 2                 NaN                NaN           None
# 3                 NaN                NaN           None
# 4                 NaN                NaN           None

# %%
## histogram for religious level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["religious_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Religious Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Religious Level (Answered Only)')

# %%
def agnost_level(ans):
    if ans == "agnosticism and laughing about it":
        return 1
    if ans == "agnosticism but not too serious about it":
        return 2
    if ans == "agnosticism":
        return 3
    if ans == "agnosticism and somewhat serious about it":
        return 4
    if ans == "agnosticism and very serious about it":
        return 5 

df2["agnosticism_level"] = df2["religion"].apply(agnost_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... Edu_Level kids_level dog_level cat_level  \
# 0               transportation  ...         2        6.0       7.0       7.0
# 1         hospitality / travel  ...         3        6.0       7.0       7.0
# 2                          NaN  ...         3        NaN       NaN      10.0
# 3                      student  ...         2        2.0       NaN       6.0
# 4  artistic / musical / writer  ...         3        NaN       7.0       7.0
#
#   smoke_level status_level  Diet_Type religious_level_no_ath_agn  \
# 0         3.0            5   Omnivore                        NaN
# 1         1.0            5      Other                        NaN
# 2         1.0            4       None                        NaN
# 3         1.0            5  Veg/Vegan                        NaN
# 4         1.0            5       None                        NaN
#
#   religious_level  agnosticism_level
# 0             NaN                5.0
# 1             NaN                2.0
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
#
# [5 rows x 32 columns]

# %%
## histogram for agnostic level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["agnosticism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Agnosticism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Agnosticism Level (Answered Only)')

# %%
def atheism_level(ans):
    if ans == "atheism and laughing about it":
        return 1
    if ans == "atheism but not too serious about it":
        return 2
    if ans == "atheism":
        return 3
    if ans == "atheism and somewhat serious about it":
        return 4
    if ans == "atheism and very serious about it":
        return 5 
    
df2["atheism_level"] = df2["religion"].apply(atheism_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... kids_level dog_level cat_level  \
# 0               transportation  ...        6.0       7.0       7.0
# 1         hospitality / travel  ...        6.0       7.0       7.0
# 2                          NaN  ...        NaN       NaN      10.0
# 3                      student  ...        2.0       NaN       6.0
# 4  artistic / musical / writer  ...        NaN       7.0       7.0
#
#   smoke_level status_level  Diet_Type religious_level_no_ath_agn  \
# 0         3.0            5   Omnivore                        NaN
# 1         1.0            5      Other                        NaN
# 2         1.0            4       None                        NaN
# 3         1.0            5  Veg/Vegan                        NaN
# 4         1.0            5       None                        NaN
#
#   religious_level agnosticism_level  atheism_level
# 0             NaN               5.0            NaN
# 1             NaN               2.0            NaN
# 2             NaN               NaN            NaN
# 3             NaN               NaN            NaN
# 4             NaN               NaN            NaN
#
# [5 rows x 33 columns]

# %%
## histogram for atheism level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["atheism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Atheism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Atheism Level (Answered Only)')

# %%
def hindu_level(ans):
    if ans == "hinduism and laughing about it":
        return 1
    if ans == "hinduism but not too serious about it":
        return 2
    if ans == "hinduism":
        return 3
    if ans == "hinduism and somewhat serious about it":
        return 4
    if ans == "hinduism and very serious about it":
        return 5 

df2["hinduism_level"] = df2["religion"].apply(hindu_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... dog_level cat_level smoke_level  \
# 0               transportation  ...       7.0       7.0         3.0
# 1         hospitality / travel  ...       7.0       7.0         1.0
# 2                          NaN  ...       NaN      10.0         1.0
# 3                      student  ...       NaN       6.0         1.0
# 4  artistic / musical / writer  ...       7.0       7.0         1.0
#
#   status_level  Diet_Type religious_level_no_ath_agn religious_level  \
# 0            5   Omnivore                        NaN             NaN
# 1            5      Other                        NaN             NaN
# 2            4       None                        NaN             NaN
# 3            5  Veg/Vegan                        NaN             NaN
# 4            5       None                        NaN             NaN
#
#   agnosticism_level atheism_level  hinduism_level
# 0               5.0           NaN             NaN
# 1               2.0           NaN             NaN
# 2               NaN           NaN             NaN
# 3               NaN           NaN             NaN
# 4               NaN           NaN             NaN
#
# [5 rows x 34 columns]

# %%
## histogram for hinduism level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["hinduism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Hinduism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Hinduism Level (Answered Only)')

# %%
def islam_level(ans):
    if ans == "islam and laughing about it":
        return 1
    if ans == "islam but not too serious about it":
        return 2
    if ans == "islam":
        return 3
    if ans == "islam and somewhat serious about it":
        return 4
    if ans == "islam and very serious about it":
        return 5 

df2["islam_level"] = df2["religion"].apply(islam_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... cat_level smoke_level status_level  \
# 0               transportation  ...       7.0         3.0            5
# 1         hospitality / travel  ...       7.0         1.0            5
# 2                          NaN  ...      10.0         1.0            4
# 3                      student  ...       6.0         1.0            5
# 4  artistic / musical / writer  ...       7.0         1.0            5
#
#    Diet_Type religious_level_no_ath_agn religious_level agnosticism_level  \
# 0   Omnivore                        NaN             NaN               5.0
# 1      Other                        NaN             NaN               2.0
# 2       None                        NaN             NaN               NaN
# 3  Veg/Vegan                        NaN             NaN               NaN
# 4       None                        NaN             NaN               NaN
#
#   atheism_level hinduism_level  islam_level
# 0           NaN            NaN          NaN
# 1           NaN            NaN          NaN
# 2           NaN            NaN          NaN
# 3           NaN            NaN          NaN
# 4           NaN            NaN          NaN
#
# [5 rows x 35 columns]

# %%
## histogram for Islam level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["islam_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Islam Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Islam Level (Answered Only)')

# %%
def bud_level(ans):
    if ans == "buddhism and laughing about it":
        return 1
    if ans == "buddhism but not too serious about it":
        return 2
    if ans == "buddhism":
        return 3
    if ans == "buddhism and somewhat serious about it":
        return 4
    if ans == "buddhism and very serious about it":
        return 5 

df2["buddhism_level"] = df2["religion"].apply(bud_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... smoke_level status_level  Diet_Type  \
# 0               transportation  ...         3.0            5   Omnivore
# 1         hospitality / travel  ...         1.0            5      Other
# 2                          NaN  ...         1.0            4       None
# 3                      student  ...         1.0            5  Veg/Vegan
# 4  artistic / musical / writer  ...         1.0            5       None
#
#   religious_level_no_ath_agn religious_level agnosticism_level atheism_level  \
# 0                        NaN             NaN               5.0           NaN
# 1                        NaN             NaN               2.0           NaN
# 2                        NaN             NaN               NaN           NaN
# 3                        NaN             NaN               NaN           NaN
# 4                        NaN             NaN               NaN           NaN
#
#   hinduism_level islam_level  buddhism_level
# 0            NaN         NaN             NaN
# 1            NaN         NaN             NaN
# 2            NaN         NaN             NaN
# 3            NaN         NaN             NaN
# 4            NaN         NaN             NaN
#
# [5 rows x 36 columns]

# %%
## histogram for buddhism level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["buddhism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Buddhism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Buddhism Level (Answered Only)')

# %%
def jud_level(ans):
    if ans == "judaism and laughing about it":
        return 1
    if ans == "judaism but not too serious about it":
        return 2
    if ans == "judaism":
        return 3
    if ans == "judaism and somewhat serious about it":
        return 4
    if ans == "judaism and very serious about it":
        return 5 

df2["judaism_level"] = df2["religion"].apply(jud_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... status_level  Diet_Type  \
# 0               transportation  ...            5   Omnivore
# 1         hospitality / travel  ...            5      Other
# 2                          NaN  ...            4       None
# 3                      student  ...            5  Veg/Vegan
# 4  artistic / musical / writer  ...            5       None
#
#   religious_level_no_ath_agn religious_level agnosticism_level atheism_level  \
# 0                        NaN             NaN               5.0           NaN
# 1                        NaN             NaN               2.0           NaN
# 2                        NaN             NaN               NaN           NaN
# 3                        NaN             NaN               NaN           NaN
# 4                        NaN             NaN               NaN           NaN
#
#   hinduism_level islam_level buddhism_level  judaism_level
# 0            NaN         NaN            NaN            NaN
# 1            NaN         NaN            NaN            NaN
# 2            NaN         NaN            NaN            NaN
# 3            NaN         NaN            NaN            NaN
# 4            NaN         NaN            NaN            NaN
#
# [5 rows x 37 columns]

# %%
## histogram for judaism level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["judaism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Judaism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Judaism Level (Answered Only)')

# %%
def christ_level(ans):
    if ans == "christianity and laughing about it":
        return 1
    if ans == "christianity but not too serious about it":
        return 2
    if ans == "christianity":
        return 3
    if ans == "christianity and somewhat serious about it":
        return 4
    if ans == "christianity and very serious about it":
        return 5 

df2["christianity_level"] = df2["religion"].apply(christ_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...  Diet_Type religious_level_no_ath_agn  \
# 0               transportation  ...   Omnivore                        NaN
# 1         hospitality / travel  ...      Other                        NaN
# 2                          NaN  ...       None                        NaN
# 3                      student  ...  Veg/Vegan                        NaN
# 4  artistic / musical / writer  ...       None                        NaN
#
#   religious_level agnosticism_level atheism_level hinduism_level islam_level  \
# 0             NaN               5.0           NaN            NaN         NaN
# 1             NaN               2.0           NaN            NaN         NaN
# 2             NaN               NaN           NaN            NaN         NaN
# 3             NaN               NaN           NaN            NaN         NaN
# 4             NaN               NaN           NaN            NaN         NaN
#
#   buddhism_level judaism_level  christianity_level
# 0            NaN           NaN                 NaN
# 1            NaN           NaN                 NaN
# 2            NaN           NaN                 NaN
# 3            NaN           NaN                 NaN
# 4            NaN           NaN                 NaN
#
# [5 rows x 38 columns]

# %%
## histogram for christianity level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["christianity_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Christianity Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Christianity Level (Answered Only)')

# %%
def cath_level(ans):
    if ans == "catholicism and laughing about it":
        return 1
    if ans == "catholicism but not too serious about it":
        return 2
    if ans == "catholicism":
        return 3
    if ans == "catholicism and somewhat serious about it":
        return 4
    if ans == "catholicism and very serious about it":
        return 5

df2["catholicism_level"] = df2["religion"].apply(cath_level)
df2.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   36         average       mostly other     often  sometimes
# 2   37            thin           anything  socially        NaN
# 3   22            thin         vegetarian  socially        NaN
# 4   30        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ... religious_level_no_ath_agn  \
# 0               transportation  ...                        NaN
# 1         hospitality / travel  ...                        NaN
# 2                          NaN  ...                        NaN
# 3                      student  ...                        NaN
# 4  artistic / musical / writer  ...                        NaN
#
#   religious_level agnosticism_level atheism_level hinduism_level islam_level  \
# 0             NaN               5.0           NaN            NaN         NaN
# 1             NaN               2.0           NaN            NaN         NaN
# 2             NaN               NaN           NaN            NaN         NaN
# 3             NaN               NaN           NaN            NaN         NaN
# 4             NaN               NaN           NaN            NaN         NaN
#
#   buddhism_level judaism_level christianity_level  catholicism_level
# 0            NaN           NaN                NaN                NaN
# 1            NaN           NaN                NaN                NaN
# 2            NaN           NaN                NaN                NaN
# 3            NaN           NaN                NaN                NaN
# 4            NaN           NaN                NaN                NaN
#
# [5 rows x 39 columns]

# %%
## histogram for catholicism level

plt.figure(figsize = (15,5))
sns.histplot(x = df2["catholicism_level"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Catholicism Level (Answered Only)")
# Out:
# Text(0.5, 1.0, 'Count of Catholicism Level (Answered Only)')

# %%
## histogram for diet

plt.figure(figsize = (15,5))
sns.histplot(x = df2["diet"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Diets")
# Out:
# Text(0.5, 1.0, 'Count of Diets')

# %%
## histogram for diet type

plt.figure(figsize = (15,5))
sns.histplot(x = df2["Diet_Type"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Diet Types")
# Out:
# Text(0.5, 1.0, 'Count of Diet Types')

# %%
## histogram for job

plt.figure(figsize = (15,5))
sns.histplot(x = df2["job"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Job Type")
# Out:
# Text(0.5, 1.0, 'Count of Job Type')

# %%
## boxplot for age

plt.figure(figsize = (15,5))
sns.boxplot(x = df2["age"])
plt.xticks(rotation = 90)
plt.title("Distribution of Ages")
# Out:
# Text(0.5, 1.0, 'Distribution of Ages')

# %%
## histogram for orientation

sns.histplot(x = df["orientation"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Orientation Type")
# Out:
# Text(0.5, 1.0, 'Count of Orientation Type')

# %%
## histogram for pets

plt.figure(figsize = (15,5))
sns.histplot(x = df["pets"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Pets Type")
# Out:
# Text(0.5, 1.0, 'Count of Pets Type')

# %%
## histogram for sex

sns.histplot(x = df2["sex"], kde = False)
plt.title("Count of Sex")
# Out:
# Text(0.5, 1.0, 'Count of Sex')

# %%
## histogram for drinking habits

plt.figure(figsize = (15,5))
sns.histplot(x = df2["drinks"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drink Types")
# Out:
# Text(0.5, 1.0, 'Count of Drink Types')

# %%
## histogram for smokes

plt.figure(figsize = (15,5))
sns.histplot(x = df["smokes"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Smokes")
# Out:
# Text(0.5, 1.0, 'Count of Smokes')

# %%
## histogram for status

sns.histplot(x = df["status"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Status")
# Out:
# Text(0.5, 1.0, 'Count of Status')

# %%
## histogram for drug habits

plt.figure(figsize = (15,5))
sns.histplot(x = df2["drugs"], kde = False)
plt.xticks(rotation = 90)
plt.title("Count of Drug Level")
# Out:
# Text(0.5, 1.0, 'Count of Drug Level')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58304 entries, 0 to 59945
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         58304 non-null  int64
#  1   body_type                   53088 non-null  object
#  2   diet                        34514 non-null  object
#  3   drinks                      55388 non-null  object
#  4   drugs                       44464 non-null  object
#  5   education                   51826 non-null  object
#  6   ethnicity                   52762 non-null  object
#  7   height                      58301 non-null  float64
#  8   income                      58304 non-null  int64
#  9   job                         50263 non-null  object
#  10  offspring                   23416 non-null  object
#  11  orientation                 58304 non-null  object
#  12  pets                        38838 non-null  object
#  13  religion                    38423 non-null  object
#  14  sex                         58304 non-null  object
#  15  sign                        47550 non-null  object
#  16  smokes                      52895 non-null  object
#  17  speaks                      58255 non-null  object
#  18  status                      58304 non-null  object
#  19  drink_level                 55388 non-null  float64
#  20  drugs_level                 44464 non-null  float64
#  21  Edu_Type                    58304 non-null  object
#  22  Edu_Level                   58304 non-null  int64
#  23  kids_level                  23416 non-null  float64
#  24  dog_level                   36341 non-null  float64
#  25  cat_level                   27709 non-null  float64
#  26  smoke_level                 52895 non-null  float64
#  27  status_level                58304 non-null  int64
#  28  Diet_Type                   6636 non-null   object
#  29  religious_level_no_ath_agn  15661 non-null  float64
#  30  religious_level             15661 non-null  float64
#  31  agnosticism_level           8595 non-null   float64
#  32  atheism_level               6812 non-null   float64
#  33  hinduism_level              444 non-null    float64
#  34  islam_level                 137 non-null    float64
#  35  buddhism_level              1860 non-null   float64
#  36  judaism_level               2944 non-null   float64
#  37  christianity_level          5607 non-null   float64
#  38  catholicism_level           4669 non-null   float64
#  39  religion_group              30931 non-null  object
#  40  income_group                53144 non-null  object
#  41  income_level                53144 non-null  float64
#  42  height_level                58177 non-null  float64
#  43  height_group                58177 non-null  object
# dtypes: float64(19), int64(4), object(21)
# memory usage: 22.0+ MB

# %% [markdown]
# ## df3: includes non-response

# %%
df3 = df2.copy()

# %%
def drink_level(drink):
    if drink == "desperately":
        return 6
    if drink == "very often":
        return 5
    if drink == "often":
        return 4
    if drink == "socially":
        return 3
    if drink == "rarely":
        return 2
    if drink == "not at all":
        return 1
    else:
        return "Unknown"

df3["drink_level"] = df3["drinks"].apply(drink_level)

# %%
def drugs_level(drug):
    if drug == "often":
        return 3
    if drug == "sometimes":
        return 2
    if drug == "never":
        return 1
    else:
        return 0

df3["drugs_level"] = df3["drugs"].apply(drugs_level)

# %%
def edu_groups(type):
    if type == ("dropped out of high school" or "working on high school" or "high school"):
        return "HS or Less"
    if type == ("working on college/university" or "graduated from college/university" or "college/university" or "two-year college" or "graduated from two-year college" or "dropped out of college/university"):
        return "2-4-Year College"
    if type == ("graduated from masters program" or "working on masters program" or"graduated from ph.d program" or "graduated from law school" or "working on ph.d program" or "graduated from space camp" or "dropped out of space camp" or "graduated from med school" or "working on space camp" or "working on law school" or "working on med school" or "dropped out of masters program" or "masters program" or "dropped out of ph.d program" or "space camp" or "ph.d program" or "law school" or "dropped out of law school" or "dropped out of med school" or "med school"):
        return "More than College"
    else:
        return "Unknown"

df3["Edu_Type"] = df3["education"].apply(edu_groups)

# %%
def edu_level(type):
    if type == "HS or Less":
        return 1
    if type == "2-4-Year College":
        return 2
    if type == "More than College":
        return 3
    else:
        return 0

df3["Edu_Level"] = df3["Edu_Type"].apply(edu_level)

# %%
def kids_level(ans):
    if ans == "has kids, and wants more":
        return 15
    if ans == "has a kid, and wants more":
        return 14
    if ans == "wants kids":
        return 13
    if ans == "doesn&rsquo;t have kids, but wants them":
        return 12
    if ans == "has kids, and might want more":
        return 11
    if ans == "has a kid, and might want more":
        return 10
    if ans == "has kids":
        return 9
    if ans == "has a kid":
        return 8
    if ans == "might want kids":
        return 7
    if ans == "doesn&rsquo;t have kids, but might want them":
        return 6
    if ans == "has kids, but doesn&rsquo;t want more":
        return 5
    if ans == "has a kid, but doesn&rsquo;t want more":
        return 4
    if ans == "doesn&rsquo;t have kids":
        return 3
    if ans == "doesn&rsquo;t want kids":
        return 2
    if ans == "doesn&rsquo;t have kids, and doesn&rsquo;t want any":
        return 1
    else:
        return 0

df3["kids_level"] = df3["offspring"].apply(kids_level)

# %%
def dog_level(ans):
    if ans == "dislikes dogs and dislikes cats":
        return 1
    if ans == "dislikes dogs":
        return 2
    if ans == "dislikes dogs and has cats":
        return 3
    if ans == "dislikes dogs and likes cats":
        return 4
    if ans == "likes dogs and has cats":
        return 5
    if ans == "likes dogs":
        return 6
    if ans == "likes dogs and likes cats":
        return 7
    if ans == "has dogs and likes cats":
        return 8
    if ans == "has dogs and has cats":
        return 9
    if ans == "has dogs":
        return 10
    if ans =="likes dogs and dislikes cats":
        return 11
    if ans == "has dogs and dislikes cats":
        return 12
    else:
        return 0

df3["dog_level"] = df3["pets"].apply(dog_level)

# %%
def cat_level(ans):
    if ans == "dislikes dogs and dislikes cats":
        return 1
    if ans == "dislikes cats":
        return 2
    if ans == "has dogs and dislikes cats":
        return 3
    if ans == "likes dogs and dislikes cats":
        return 4
    if ans == "has dogs and likes cats":
        return 5
    if ans == "likes cats":
        return 6
    if ans == "likes dogs and likes cats":
        return 7
    if ans == "likes dogs and has cats":
        return 8
    if ans == "has dogs and has cats":
        return 9
    if ans == "has cats":
        return 10
    if ans =="dislikes dogs and likes cats":
        return 11
    if ans == "dislikes dogs and has cats":
        return 12
    else:
        return 0

df3["cat_level"] = df3["pets"].apply(cat_level)

# %%
def smoke_level(ans):
    if ans == "no":
        return 1
    if ans == "when drinking":
        return 2
    if ans == "sometimes":
        return 3
    if ans == "trying to quit":
        return 4
    if ans == "yes":
        return 5
    else:
        return 0

df3["smoke_level"] = df3["smokes"].apply(smoke_level)

# %%
def status_level(ans):
    if ans == "unknown":
        return 1
    if ans == "married":
        return 2
    if ans == "seeing someone":
        return 3
    if ans == "available":
        return 4
    if ans == "single":
        return 5
    else:
        return 0

df3["status_level"] = df3["status"].apply(status_level)

# %%
def diet_groups(type):
    if type == ("vegetarian" or "mostly vegetarian" or "strictly vegan" or "strictly vegetarian" or "mostly vegan" or "vegan"):
        return "Veg/Vegan"
    if type == ("strictly anything" or "anything" or "mostly anything"):
        return "Omnivore"
    if type == ("mostly halal" or "mostly kosher" or "halal" or "strictly halal" or "kosher" or "strictly kosher"):
        return "Religion-based"
    if type == ("mostly other" or "strictly other" or "other"):
        return "Other"
    else:
        return "Unknown"

df3["Diet_Type"] = df3["diet"].apply(diet_groups)

# %%
def rel_level_2(ans):
    if ans == "hinduism and laughing about it":
        return 1
    if ans == "islam and laughing about it":
        return 1
    if ans == "buddhism and laughing about it":
        return 1
    if ans == "judaism and laughing about it":
        return 1
    if ans == "christianity and laughing about it":
        return 1
    if ans == "catholicism and laughing about it":
        return 1
    if ans == "hinduism but not too serious about it":
        return 2
    if ans == "islam but not too serious about it":
        return 2
    if ans == "buddhism but not too serious about it":
        return 2
    if ans == "judaism but not too serious about it":
        return 2
    if ans == "christianity but not too serious about it":
        return 2
    if ans == "catholicism but not too serious about it":
        return 2
    if ans == "hinduism":
        return 3
    if ans == "islam":
        return 3
    if ans == "buddhism":
        return 3
    if ans == "judaism":
        return 3
    if ans == "christianity":
        return 3
    if ans == "catholicism":
        return 3
    if ans == "hinduism and somewhat serious about it":
        return 4
    if ans == "islam and somewhat serious about it":
        return 4
    if ans == "buddhism and somewhat serious about it":
        return 4
    if ans == "judaism and somewhat serious about it":
        return 4
    if ans == "christianity and somewhat serious about it":
        return 4
    if ans == "catholicism and somewhat serious about it":
        return 4
    if ans == "hinduism and very serious about it":
        return 5 
    if ans == "islam and very serious about it":
        return 5 
    if ans == "buddhism and very serious about it":
        return 5 
    if ans == "judaism and very serious about it":
        return 5 
    if ans == "christianity and very serious about it":
        return 5 
    if ans == "catholicism and very serious about it":
        return 5 
    else:
        return 0
    
df3["religious_level_no_ath_agn"] = df3["religion"].apply(rel_level_2)

# %%
def rel_level(ans):
    if ans == "agnosticism and laughing about it":
        return 1
    if ans == "agnosticism but not too serious about it":
        return 1
    if ans == "agnosticism":
        return 1
    if ans == "agnosticism and somewhat serious about it":
        return 1
    if ans == "agnosticism and very serious about it":
        return 1
    if ans == "atheism and laughing about it":
        return 1
    if ans == "atheism but not too serious about it":
        return 1
    if ans == "atheism":
        return 1
    if ans == "atheism and somewhat serious about it":
        return 1
    if ans == "atheism and very serious about it":
        return 1
    if ans == "hinduism and laughing about it":
        return 1
    if ans == "islam and laughing about it":
        return 1
    if ans == "buddhism and laughing about it":
        return 1
    if ans == "judaism and laughing about it":
        return 1
    if ans == "christianity and laughing about it":
        return 1
    if ans == "catholicism and laughing about it":
        return 1
    if ans == "hinduism but not too serious about it":
        return 2
    if ans == "islam but not too serious about it":
        return 2
    if ans == "buddhism but not too serious about it":
        return 2
    if ans == "judaism but not too serious about it":
        return 2
    if ans == "christianity but not too serious about it":
        return 2
    if ans == "catholicism but not too serious about it":
        return 2
    if ans == "hinduism":
        return 3
    if ans == "islam":
        return 3
    if ans == "buddhism":
        return 3
    if ans == "judaism":
        return 3
    if ans == "christianity":
        return 3
    if ans == "catholicism":
        return 3
    if ans == "hinduism and somewhat serious about it":
        return 4
    if ans == "islam and somewhat serious about it":
        return 4
    if ans == "buddhism and somewhat serious about it":
        return 4
    if ans == "judaism and somewhat serious about it":
        return 4
    if ans == "christianity and somewhat serious about it":
        return 4
    if ans == "catholicism and somewhat serious about it":
        return 4
    if ans == "hinduism and very serious about it":
        return 5 
    if ans == "islam and very serious about it":
        return 5 
    if ans == "buddhism and very serious about it":
        return 5 
    if ans == "judaism and very serious about it":
        return 5 
    if ans == "christianity and very serious about it":
        return 5 
    if ans == "catholicism and very serious about it":
        return 5
    else:
        return 0
    
df3["religious_level"] = df3["religion"].apply(rel_level_2)

# %%
def rel_group(ans):
    if ans == "judaism and laughing about it":
        return "Jewish"
    if ans == "judaism but not too serious about it":
        return "Jewish"
    if ans == "judaism":
        return "Jewish"
    if ans == "judaism and somewhat serious about it":
        return "Jewish"
    if ans == "judaism and very serious about it":
        return "Jewish" 
    if ans == "catholicism and laughing about it":
        return "Catholic"
    if ans == "catholicism but not too serious about it":
        return "Catholic"
    if ans == "catholicism":
        return "Catholic"
    if ans == "catholicism and somewhat serious about it":
        return "Catholic"
    if ans == "catholicism and very serious about it":
        return "Catholic" 
    if ans == "christianity and laughing about it":
        return "Christian"
    if ans == "christianity but not too serious about it":
        return "Christian"
    if ans == "christianity":
        return "Christian"
    if ans == "christianity and somewhat serious about it":
        return "Christian"
    if ans == "christianity and very serious about it":
        return "Christian"
    if ans == "hinduism and laughing about it":
        return "Hindu"
    if ans == "hinduism but not too serious about it":
        return "Hindu"
    if ans == "hinduism":
        return "Hindu"
    if ans == "hinduism and somewhat serious about it":
        return "Hindu"
    if ans == "hinduism and very serious about it":
        return "Hindu" 
    if ans == "buddhism and laughing about it":
        return "Buddhist"
    if ans == "buddhism but not too serious about it":
        return "Buddhist"
    if ans == "buddhism":
        return "Buddhist"
    if ans == "buddhism and somewhat serious about it":
        return "Buddhist"
    if ans == "buddhism and very serious about it":
        return "Buddhist" 
    if ans == "agnosticism and laughing about it":
        return "Agnostic"
    if ans == "agnosticism but not too serious about it":
        return "Agnostic"
    if ans == "agnosticism":
        return "Agnostic"
    if ans == "agnosticism and somewhat serious about it":
        return "Agnostic"
    if ans == "agnosticism and very serious about it":
        return "Agnostic"
    if ans == "atheism and laughing about it":
        return "Atheist"
    if ans == "atheism but not too serious about it":
        return "Atheist"
    if ans == "atheism":
        return "Atheist"
    if ans == "atheism and somewhat serious about it":
        return "Atheist"
    if ans == "atheism and very serious about it":
        return "Atheist"
    else:
        return "Unknown"

df3["religion_group"] = df3["religion"].apply(rel_group)

# %%
def inc_group(ans):
    if ans == (20000 or 30000 or 40000):
        return "$20K-$49K"
    if ans == (50000 or 60000 or 70000):
        return "$50K-$79K"
    if ans == (80000 or 100000):
        return "$80K-$149K"
    if ans == (150000 or 250000):
        return "$150K+"
    else:
        return "Unknown"
    
df3["income_group"] = df3["income"].apply(inc_group)

# %%
def inc_level(ans):
    if ans == "Unknown":
        return 0
    if ans == "$20K-$49K":
        return 1
    if ans == "$50K-$79K":
        return 2
    if ans == "$80K-$149K":
        return 3
    if ans == "$150K+":
        return 4
    else:
        return 0

df3["income_level"] = df3["income_group"].apply(inc_level)

# %%
def hgt_group(ans):
    if ans < 48:
        return "less than 4'"
    if (ans >= 48 and ans < 60):
        return "4' - 4'11"
    if (ans >= 60 and ans <66):
        return "5' - 5'5"
    if (ans >= 66 and ans <72):
        return "5'6 - 5'11"
    if (ans >= 72 and ans <78):
        return "6' - 6'5"
    if (ans >78):
        return "6'6+"
    else:
        return "Unknown"

df3["height_group"] = df3["height"].apply(hgt_group)

# %%
def hgt_level(ans):
    if ans < 48:
        return 1
    if (ans >= 48 and ans < 60):
        return 2
    if (ans >= 60 and ans <66):
        return 3
    if (ans >= 66 and ans <72):
        return 4
    if (ans >= 72 and ans <78):
        return 5
    if (ans >78):
        return 6
    else:
        return 0

df3["height_level"] = df3["height"].apply(hgt_level)

# %% [markdown]
# ## Correlations Between Numeric Variables

# %%
pd.set_option('display.max_columns', None) ## show all the columns in dataset
pd.set_option('display.max_rows', None) ## show all rows in dataset

# %% [markdown]
# ### Correlations from Responses Only

# %%
df2.corr()
# Out:
#                                  age    height    income  drink_level  \
# age                         1.000000 -0.011359  0.105166    -0.113383
# height                     -0.011359  1.000000  0.111291     0.031882
# income                      0.105166  0.111291  1.000000     0.001929
# drink_level                -0.113383  0.031882  0.001929     1.000000
# drugs_level                -0.139863  0.070191  0.008607     0.212569
# Edu_Level                   0.553639 -0.017906  0.102289     0.007625
# kids_level                  0.090554 -0.056963  0.047893    -0.052553
# dog_level                  -0.026459 -0.024843  0.002110    -0.002445
# cat_level                   0.092921 -0.009042  0.010961    -0.022653
# smoke_level                -0.137138  0.039928 -0.004151     0.128587
# status_level                0.015193  0.006436 -0.010370     0.003699
# religious_level_no_ath_agn  0.002199 -0.064833 -0.013308    -0.130873
# religious_level             0.002199 -0.064833 -0.013308    -0.130873
# agnosticism_level           0.029841 -0.037128  0.000046    -0.014226
# atheism_level               0.013753 -0.037333 -0.005079    -0.017711
# hinduism_level              0.008958 -0.008240  0.013675    -0.158279
# islam_level                -0.135163  0.090514 -0.174712    -0.101997
# buddhism_level              0.068068 -0.102315 -0.007650    -0.111860
# judaism_level               0.044662 -0.053255 -0.033881    -0.056943
# christianity_level         -0.001333 -0.103694 -0.024283    -0.154842
# catholicism_level          -0.002876 -0.089814 -0.024276    -0.092942
# income_level                0.455406  0.126361  0.976425     0.039253
# height_level               -0.008399  0.905121  0.104197     0.029867
# pet_level                   0.070556 -0.078671 -0.016810    -0.020674
#
#                             drugs_level     Edu_Level  kids_level  dog_level  \
# age                           -0.139863  5.536387e-01    0.090554  -0.026459
# height                         0.070191 -1.790640e-02   -0.056963  -0.024843
# income                         0.008607  1.022887e-01    0.047893   0.002110
# drink_level                    0.212569  7.624793e-03   -0.052553  -0.002445
# drugs_level                    1.000000 -2.283865e-01   -0.151556  -0.041253
# Edu_Level                     -0.228386  1.000000e+00    0.119107  -0.079665
# kids_level                    -0.151556  1.191071e-01    1.000000   0.069856
# dog_level                     -0.041253 -7.966472e-02    0.069856   1.000000
# cat_level                      0.049672 -3.043976e-03   -0.038039  -0.577113
# smoke_level                    0.337310 -3.140086e-01   -0.062582   0.017541
# status_level                  -0.088802  6.284419e-02    0.056497   0.039504
# religious_level_no_ath_agn    -0.126318 -5.236832e-02    0.116987   0.035057
# religious_level               -0.126318 -5.236832e-02    0.116987   0.035057
# agnosticism_level             -0.014659  8.600942e-02    0.004022   0.007287
# atheism_level                 -0.003087 -1.179002e-02   -0.042022  -0.046655
# hinduism_level                 0.064081 -4.340230e-02   -0.144119  -0.039082
# islam_level                    0.035611  5.810592e-17    0.119357  -0.109776
# buddhism_level                -0.137379  7.325844e-02    0.037267   0.007253
# judaism_level                 -0.133550  7.253514e-02    0.139594   0.018678
# christianity_level            -0.094611 -6.255724e-02    0.127010   0.020934
# catholicism_level             -0.117302 -4.138112e-02    0.126937   0.069038
# income_level                  -0.218087  7.317128e-01    0.122406  -0.012161
# height_level                   0.065025 -1.892555e-02   -0.052995  -0.025352
# pet_level                     -0.024765 -5.551482e-02    0.040741  -0.029414
#
#                             cat_level  smoke_level  status_level  \
# age                          0.092921    -0.137138      0.015193
# height                      -0.009042     0.039928      0.006436
# income                       0.010961    -0.004151     -0.010370
# drink_level                 -0.022653     0.128587      0.003699
# drugs_level                  0.049672     0.337310     -0.088802
# Edu_Level                   -0.003044    -0.314009      0.062844
# kids_level                  -0.038039    -0.062582      0.056497
# dog_level                   -0.577113     0.017541      0.039504
# cat_level                    1.000000     0.033960     -0.062733
# smoke_level                  0.033960     1.000000     -0.005986
# status_level                -0.062733    -0.005986      1.000000
# religious_level_no_ath_agn  -0.024897    -0.026237      0.036422
# religious_level             -0.024897    -0.026237      0.036422
# agnosticism_level           -0.013111     0.001446      0.019644
# atheism_level                0.052146     0.032614     -0.058843
# hinduism_level               0.032697    -0.037229     -0.019227
# islam_level                 -0.118330     0.082164      0.030208
# buddhism_level               0.041935    -0.000031      0.065079
# judaism_level               -0.004238    -0.083633      0.048227
# christianity_level          -0.031913    -0.048506      0.005446
# catholicism_level           -0.034860    -0.032088      0.049566
# income_level                -0.001068    -0.248895      0.086341
# height_level                -0.007098     0.038600      0.005504
# pet_level                    0.389370     0.019126     -0.019908
#
#                             religious_level_no_ath_agn  religious_level  \
# age                                           0.002199         0.002199
# height                                       -0.064833        -0.064833
# income                                       -0.013308        -0.013308
# drink_level                                  -0.130873        -0.130873
# drugs_level                                  -0.126318        -0.126318
# Edu_Level                                    -0.052368        -0.052368
# kids_level                                    0.116987         0.116987
# dog_level                                     0.035057         0.035057
# cat_level                                    -0.024897        -0.024897
# smoke_level                                  -0.026237        -0.026237
# status_level                                  0.036422         0.036422
# religious_level_no_ath_agn                    1.000000         1.000000
# religious_level                               1.000000         1.000000
# agnosticism_level                                  NaN              NaN
# atheism_level                                      NaN              NaN
# hinduism_level                                1.000000         1.000000
# islam_level                                   1.000000         1.000000
# buddhism_level                                1.000000         1.000000
# judaism_level                                 1.000000         1.000000
# christianity_level                            1.000000         1.000000
# catholicism_level                             1.000000         1.000000
# income_level                                 -0.122396        -0.122396
# height_level                                 -0.066443        -0.066443
# pet_level                                     0.000488         0.000488
#
#                             agnosticism_level  atheism_level  hinduism_level  \
# age                                  0.029841       0.013753        0.008958
# height                              -0.037128      -0.037333       -0.008240
# income                               0.000046      -0.005079        0.013675
# drink_level                         -0.014226      -0.017711       -0.158279
# drugs_level                         -0.014659      -0.003087        0.064081
# Edu_Level                            0.086009      -0.011790       -0.043402
# kids_level                           0.004022      -0.042022       -0.144119
# dog_level                            0.007287      -0.046655       -0.039082
# cat_level                           -0.013111       0.052146        0.032697
# smoke_level                          0.001446       0.032614       -0.037229
# status_level                         0.019644      -0.058843       -0.019227
# religious_level_no_ath_agn                NaN            NaN        1.000000
# religious_level                           NaN            NaN        1.000000
# agnosticism_level                    1.000000            NaN             NaN
# atheism_level                             NaN       1.000000             NaN
# hinduism_level                            NaN            NaN        1.000000
# islam_level                               NaN            NaN             NaN
# buddhism_level                            NaN            NaN             NaN
# judaism_level                             NaN            NaN             NaN
# christianity_level                        NaN            NaN             NaN
# catholicism_level                         NaN            NaN             NaN
# income_level                         0.093200      -0.008213       -0.191486
# height_level                        -0.028490      -0.038779       -0.042828
# pet_level                            0.014023       0.017157        0.009306
#
#                              islam_level  buddhism_level  judaism_level  \
# age                        -1.351631e-01        0.068068       0.044662
# height                      9.051430e-02       -0.102315      -0.053255
# income                     -1.747118e-01       -0.007650      -0.033881
# drink_level                -1.019965e-01       -0.111860      -0.056943
# drugs_level                 3.561141e-02       -0.137379      -0.133550
# Edu_Level                   5.810592e-17        0.073258       0.072535
# kids_level                  1.193570e-01        0.037267       0.139594
# dog_level                  -1.097764e-01        0.007253       0.018678
# cat_level                  -1.183302e-01        0.041935      -0.004238
# smoke_level                 8.216369e-02       -0.000031      -0.083633
# status_level                3.020825e-02        0.065079       0.048227
# religious_level_no_ath_agn  1.000000e+00        1.000000       1.000000
# religious_level             1.000000e+00        1.000000       1.000000
# agnosticism_level                    NaN             NaN            NaN
# atheism_level                        NaN             NaN            NaN
# hinduism_level                       NaN             NaN            NaN
# islam_level                 1.000000e+00             NaN            NaN
# buddhism_level                       NaN        1.000000            NaN
# judaism_level                        NaN             NaN       1.000000
# christianity_level                   NaN             NaN            NaN
# catholicism_level                    NaN             NaN            NaN
# income_level                1.010797e-01       -0.048931      -0.073571
# height_level                8.459233e-02       -0.109588      -0.062618
# pet_level                  -1.707360e-01        0.035274       0.008586
#
#                             christianity_level  catholicism_level  \
# age                                  -0.001333          -0.002876
# height                               -0.103694          -0.089814
# income                               -0.024283          -0.024276
# drink_level                          -0.154842          -0.092942
# drugs_level                          -0.094611          -0.117302
# Edu_Level                            -0.062557          -0.041381
# kids_level                            0.127010           0.126937
# dog_level                             0.020934           0.069038
# cat_level                            -0.031913          -0.034860
# smoke_level                          -0.048506          -0.032088
# status_level                          0.005446           0.049566
# religious_level_no_ath_agn            1.000000           1.000000
# religious_level                       1.000000           1.000000
# agnosticism_level                          NaN                NaN
# atheism_level                              NaN                NaN
# hinduism_level                             NaN                NaN
# islam_level                                NaN                NaN
# buddhism_level                             NaN                NaN
# judaism_level                              NaN                NaN
# christianity_level                    1.000000                NaN
# catholicism_level                          NaN           1.000000
# income_level                         -0.111804          -0.039736
# height_level                         -0.105330          -0.077855
# pet_level                            -0.006872           0.032517
#
#                             income_level  height_level  pet_level
# age                             0.455406     -0.008399   0.070556
# height                          0.126361      0.905121  -0.078671
# income                          0.976425      0.104197  -0.016810
# drink_level                     0.039253      0.029867  -0.020674
# drugs_level                    -0.218087      0.065025  -0.024765
# Edu_Level                       0.731713     -0.018926  -0.055515
# kids_level                      0.122406     -0.052995   0.040741
# dog_level                      -0.012161     -0.025352  -0.029414
# cat_level                      -0.001068     -0.007098   0.389370
# smoke_level                    -0.248895      0.038600   0.019126
# status_level                    0.086341      0.005504  -0.019908
# religious_level_no_ath_agn     -0.122396     -0.066443   0.000488
# religious_level                -0.122396     -0.066443   0.000488
# agnosticism_level               0.093200     -0.028490   0.014023
# atheism_level                  -0.008213     -0.038779   0.017157
# hinduism_level                 -0.191486     -0.042828   0.009306
# islam_level                     0.101080      0.084592  -0.170736
# buddhism_level                 -0.048931     -0.109588   0.035274
# judaism_level                  -0.073571     -0.062618   0.008586
# christianity_level             -0.111804     -0.105330  -0.006872
# catholicism_level              -0.039736     -0.077855   0.032517
# income_level                    1.000000      0.121668  -0.004495
# height_level                    0.121668      1.000000  -0.067098
# pet_level                      -0.004495     -0.067098   1.000000

# %% [markdown]
# ### Strongest Correlations:
# - dog level and cat level (-0.577)
# - smoke level and drug level (0.337)
# - drinks level and drugs level (0.213)
# - kids level and drugs level (-0.152)
# - drink level and smoke level (0.129)
# - height and income (0.111)
# - income and education level (0.102)

# %% [markdown]
# #### Related to Age
# - education level and age (0.553)
# - income level and age (0.455)
# - age and drugs level (-0.140)
# - smoke level and age (-0.137)
# - drink level and age (-0.113)
# - income and age (0.105)

# %% [markdown]
# #### Related to Religion
# - religious level and kids level (0.250)
# - religious level and drugs level (-0.198)
# - islam level and income (-0.174)
# - hinduism level and kids level (-0.144)
# - judaism level and kids level (0.140)
# - buddhism level and drugs level (-0.137)
# - judaism level and drugs level (-0.134)
# - religious level and height (-0.134)
# - religious level and drink level (-0.132)
# - christianity level and kids level (0.127)
# - catholicism level and kids level (0.127)
# - religious level (no ath or agn) and drugs level (-0.126)
# - islam level and cat level (-0.118)
# - religious level (no ath or agn) and kids level (0.117)
# - islam level and dog level (-0.110)
# - christianity level and height (-0.104)

# %% [markdown]
# ### Correlations Including Non-Response

# %%
df3.corr()
# Out:
#                                  age    height    income  drugs_level  \
# age                         1.000000 -0.011359  0.105166    -0.047990
# height                     -0.011359  1.000000  0.111291     0.009975
# income                      0.105166  0.111291  1.000000     0.055008
# drugs_level                -0.047990  0.009975  0.055008     1.000000
# Edu_Level                   0.032805 -0.038596  0.021239     0.006965
# kids_level                  0.145765 -0.048813  0.073489     0.017175
# dog_level                   0.006669 -0.041197  0.039310     0.028697
# cat_level                   0.046422 -0.031219  0.042875     0.057736
# smoke_level                -0.095704  0.028693  0.018563     0.200907
# status_level                0.015193  0.006436 -0.010370    -0.039761
# religious_level_no_ath_agn  0.043081 -0.091036  0.025718     0.033349
# religious_level             0.043081 -0.091036  0.025718     0.033349
# agnosticism_level           0.029841 -0.037128  0.000046    -0.012290
# atheism_level               0.013753 -0.037333 -0.005079     0.028282
# hinduism_level              0.008958 -0.008240  0.013675     0.149089
# islam_level                -0.135163  0.090514 -0.174712     0.051168
# buddhism_level              0.068068 -0.102315 -0.007650    -0.015042
# judaism_level               0.044662 -0.053255 -0.033881    -0.015185
# christianity_level         -0.001333 -0.103694 -0.024283     0.038068
# catholicism_level          -0.002876 -0.089814 -0.024276     0.032133
# income_level                0.039300  0.062852  0.598905     0.059943
# height_level               -0.007126  0.841931  0.099191     0.011147
# pet_level                   0.070556 -0.078671 -0.016810    -0.018154
#
#                             Edu_Level  kids_level  dog_level  cat_level  \
# age                          0.032805    0.145765   0.006669   0.046422
# height                      -0.038596   -0.048813  -0.041197  -0.031219
# income                       0.021239    0.073489   0.039310   0.042875
# drugs_level                  0.006965    0.017175   0.028697   0.057736
# Edu_Level                    1.000000    0.016446   0.016180   0.011728
# kids_level                   0.016446    1.000000   0.123086   0.069425
# dog_level                    0.016180    0.123086   1.000000   0.409376
# cat_level                    0.011728    0.069425   0.409376   1.000000
# smoke_level                 -0.035553    0.010688   0.068494   0.099468
# status_level                 0.014725    0.046207  -0.020356  -0.094528
# religious_level_no_ath_agn   0.030793    0.124229   0.051762  -0.044291
# religious_level              0.030793    0.124229   0.051762  -0.044291
# agnosticism_level            0.016027    0.003411  -0.052929  -0.070085
# atheism_level                0.009434   -0.016413  -0.044526   0.021566
# hinduism_level              -0.100821    0.032462  -0.027555  -0.018912
# islam_level                  0.076780    0.118435  -0.138754  -0.139275
# buddhism_level               0.025699    0.003438   0.004403  -0.007393
# judaism_level                0.074540    0.057575  -0.069088  -0.068816
# christianity_level          -0.019940    0.090006  -0.056549  -0.056099
# catholicism_level           -0.023612    0.079613  -0.080864  -0.152475
# income_level                 0.015844    0.049850   0.043731   0.052293
# height_level                -0.039296   -0.042990  -0.034906  -0.028569
# pet_level                   -0.006631    0.021720  -0.016113  -0.220943
#
#                             smoke_level  status_level  \
# age                           -0.095704      0.015193
# height                         0.028693      0.006436
# income                         0.018563     -0.010370
# drugs_level                    0.200907     -0.039761
# Edu_Level                     -0.035553      0.014725
# kids_level                     0.010688      0.046207
# dog_level                      0.068494     -0.020356
# cat_level                      0.099468     -0.094528
# smoke_level                    1.000000     -0.015510
# status_level                  -0.015510      1.000000
# religious_level_no_ath_agn    -0.007266      0.044002
# religious_level               -0.007266      0.044002
# agnosticism_level             -0.008868      0.019644
# atheism_level                  0.041658     -0.058843
# hinduism_level                -0.040975     -0.019227
# islam_level                    0.101734      0.030208
# buddhism_level                 0.008995      0.065079
# judaism_level                 -0.079151      0.048227
# christianity_level            -0.041183      0.005446
# catholicism_level             -0.037008      0.049566
# income_level                   0.038100     -0.014855
# height_level                   0.027704      0.006801
# pet_level                      0.010909     -0.019908
#
#                             religious_level_no_ath_agn  religious_level  \
# age                                           0.043081         0.043081
# height                                       -0.091036        -0.091036
# income                                        0.025718         0.025718
# drugs_level                                   0.033349         0.033349
# Edu_Level                                     0.030793         0.030793
# kids_level                                    0.124229         0.124229
# dog_level                                     0.051762         0.051762
# cat_level                                    -0.044291        -0.044291
# smoke_level                                  -0.007266        -0.007266
# status_level                                  0.044002         0.044002
# religious_level_no_ath_agn                    1.000000         1.000000
# religious_level                               1.000000         1.000000
# agnosticism_level                                  NaN              NaN
# atheism_level                                      NaN              NaN
# hinduism_level                                1.000000         1.000000
# islam_level                                   1.000000         1.000000
# buddhism_level                                1.000000         1.000000
# judaism_level                                 1.000000         1.000000
# christianity_level                            1.000000         1.000000
# catholicism_level                             1.000000         1.000000
# income_level                                  0.019996         0.019996
# height_level                                 -0.081973        -0.081973
# pet_level                                    -0.011362        -0.011362
#
#                             agnosticism_level  atheism_level  hinduism_level  \
# age                                  0.029841       0.013753        0.008958
# height                              -0.037128      -0.037333       -0.008240
# income                               0.000046      -0.005079        0.013675
# drugs_level                         -0.012290       0.028282        0.149089
# Edu_Level                            0.016027       0.009434       -0.100821
# kids_level                           0.003411      -0.016413        0.032462
# dog_level                           -0.052929      -0.044526       -0.027555
# cat_level                           -0.070085       0.021566       -0.018912
# smoke_level                         -0.008868       0.041658       -0.040975
# status_level                         0.019644      -0.058843       -0.019227
# religious_level_no_ath_agn                NaN            NaN        1.000000
# religious_level                           NaN            NaN        1.000000
# agnosticism_level                    1.000000            NaN             NaN
# atheism_level                             NaN       1.000000             NaN
# hinduism_level                            NaN            NaN        1.000000
# islam_level                               NaN            NaN             NaN
# buddhism_level                            NaN            NaN             NaN
# judaism_level                             NaN            NaN             NaN
# christianity_level                        NaN            NaN             NaN
# catholicism_level                         NaN            NaN             NaN
# income_level                         0.014119      -0.001077       -0.082567
# height_level                        -0.025633      -0.044275       -0.042828
# pet_level                            0.014023       0.017157        0.009306
#
#                             islam_level  buddhism_level  judaism_level  \
# age                           -0.135163        0.068068       0.044662
# height                         0.090514       -0.102315      -0.053255
# income                        -0.174712       -0.007650      -0.033881
# drugs_level                    0.051168       -0.015042      -0.015185
# Edu_Level                      0.076780        0.025699       0.074540
# kids_level                     0.118435        0.003438       0.057575
# dog_level                     -0.138754        0.004403      -0.069088
# cat_level                     -0.139275       -0.007393      -0.068816
# smoke_level                    0.101734        0.008995      -0.079151
# status_level                   0.030208        0.065079       0.048227
# religious_level_no_ath_agn     1.000000        1.000000       1.000000
# religious_level                1.000000        1.000000       1.000000
# agnosticism_level                   NaN             NaN            NaN
# atheism_level                       NaN             NaN            NaN
# hinduism_level                      NaN             NaN            NaN
# islam_level                    1.000000             NaN            NaN
# buddhism_level                      NaN        1.000000            NaN
# judaism_level                       NaN             NaN       1.000000
# christianity_level                  NaN             NaN            NaN
# catholicism_level                   NaN             NaN            NaN
# income_level                  -0.053518       -0.018501      -0.038571
# height_level                   0.084592       -0.109790      -0.062618
# pet_level                     -0.170736        0.035274       0.008586
#
#                             christianity_level  catholicism_level  \
# age                                  -0.001333          -0.002876
# height                               -0.103694          -0.089814
# income                               -0.024283          -0.024276
# drugs_level                           0.038068           0.032133
# Edu_Level                            -0.019940          -0.023612
# kids_level                            0.090006           0.079613
# dog_level                            -0.056549          -0.080864
# cat_level                            -0.056099          -0.152475
# smoke_level                          -0.041183          -0.037008
# status_level                          0.005446           0.049566
# religious_level_no_ath_agn            1.000000           1.000000
# religious_level                       1.000000           1.000000
# agnosticism_level                          NaN                NaN
# atheism_level                              NaN                NaN
# hinduism_level                             NaN                NaN
# islam_level                                NaN                NaN
# buddhism_level                             NaN                NaN
# judaism_level                              NaN                NaN
# christianity_level                    1.000000                NaN
# catholicism_level                          NaN           1.000000
# income_level                         -0.004753          -0.006597
# height_level                         -0.104498          -0.077907
# pet_level                            -0.006872           0.032517
#
#                             income_level  height_level  pet_level
# age                             0.039300     -0.007126   0.070556
# height                          0.062852      0.841931  -0.078671
# income                          0.598905      0.099191  -0.016810
# drugs_level                     0.059943      0.011147  -0.018154
# Edu_Level                       0.015844     -0.039296  -0.006631
# kids_level                      0.049850     -0.042990   0.021720
# dog_level                       0.043731     -0.034906  -0.016113
# cat_level                       0.052293     -0.028569  -0.220943
# smoke_level                     0.038100      0.027704   0.010909
# status_level                   -0.014855      0.006801  -0.019908
# religious_level_no_ath_agn      0.019996     -0.081973  -0.011362
# religious_level                 0.019996     -0.081973  -0.011362
# agnosticism_level               0.014119     -0.025633   0.014023
# atheism_level                  -0.001077     -0.044275   0.017157
# hinduism_level                 -0.082567     -0.042828   0.009306
# islam_level                    -0.053518      0.084592  -0.170736
# buddhism_level                 -0.018501     -0.109790   0.035274
# judaism_level                  -0.038571     -0.062618   0.008586
# christianity_level             -0.004753     -0.104498  -0.006872
# catholicism_level              -0.006597     -0.077907   0.032517
# income_level                    1.000000      0.056923  -0.009985
# height_level                    0.056923      1.000000  -0.063126
# pet_level                      -0.009985     -0.063126   1.000000

# %% [markdown]
# ### Related to Age
# - age and kids level (0.146)
# - age and islam level (-0.135)
# - age and income (0.105)

# %% [markdown]
# ### Related to Religion
# - religious level and kids level (0.124)
# - islam level and kids level (0.118)
# - catholicism level and cat level (-0.152)
# - islam level and dog level (-0.139)
# - islam level and cat level (-0.139)
# - buddhism level and height level (-0.110)
# - islam level and smoke level (0.101)

# %% [markdown]
# ### Related to Pets
# - dog level and cat level (0.409)
# - age and kids level (0.146)
# - catholicism level and cat level (-0.154)
# - islam level and dog level (-0.139)
# - islam level and cat level (-0.139)
# - dog level and kid level (0.123)

# %% [markdown]
# # Visuals

# %%
# boxplot of age per sex
pal = sns.color_palette("flare")

sns.boxplot(x = df2["sex"], y = df2["age"], palette=np.array(pal[::4]))

plt.title('Distribution of Ages by Sex')
plt.savefig("OKCupidAgeSex.png")
plt.show()

# %%
# boxplot of age per sex
pal = sns.color_palette("flare")

sns.barplot(x = df2["income_group"], y = df2["age"], ci = None, palette=np.array(pal[::4]))
plt.ylim([18, 40])
plt.title('Average Age by Income Group')
plt.savefig("OKCupidAgeInc.png")
plt.show()

# %%
# scatter plot of dog level and cat level for all responses, including no response
plt.title('Dog Level vs. Cat Level (All)')
plt.savefig("OKCupidDogCatAll.png")
plt.grid()
plt.show()

# %%
# scatter plot of dog level and cat level for only responses including one or the other
sns.regplot(x = df2["dog_level"], y = df2["cat_level"], fit_reg = True, color = "r")
plt.title('Dog Level vs. Cat Level (Dog vs. Cat Responses Only)')
plt.savefig("OKCupidDogCat.png")
plt.grid()
plt.show()

# %%
# scatter plot of height vs income
plt.figure(figsize = (15,5))
sns.regplot(x = df2["income"], y = df2["height"], fit_reg = True, color = "b")
plt.title('Income vs. Height')
plt.savefig("OKCupidIncHgt.png")
plt.grid()
plt.show()

# %% [markdown]
# ## Religion Visuals

# %%
# boxplot of religious group vs age
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(x = df2["religion_group"], y = df2["age"], hue = df2["sex"], ci = None, palette=np.array(pal[::4]))
plt.title('Age by Religious Groups and dSex')

plt.ylim([18, 40])
plt.savefig("OKCupidRelAgeSex.png")
plt.show()

# %%
df4_inc = df3.copy()

# %% [markdown]
# ### df4_inc: dataset with only people who answered income

# %%
#creating dataset with only people who answered income

df4_inc["inc"] = np.where(df4_inc["income"]>=0, "Y", "N")

df4_inc.drop(df4_inc.loc[df4_inc["inc"]=="N"].index, inplace = True)
df4_inc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10728 entries, 1 to 59943
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         10728 non-null  int64
#  1   body_type                   10199 non-null  object
#  2   diet                        6914 non-null   object
#  3   drinks                      10529 non-null  object
#  4   drugs                       9062 non-null   object
#  5   education                   10049 non-null  object
#  6   ethnicity                   10086 non-null  object
#  7   height                      10728 non-null  float64
#  8   income                      10728 non-null  int64
#  9   job                         10433 non-null  object
#  10  offspring                   5216 non-null   object
#  11  orientation                 10728 non-null  object
#  12  pets                        8120 non-null   object
#  13  religion                    8396 non-null   object
#  14  sex                         10728 non-null  object
#  15  sign                        9484 non-null   object
#  16  smokes                      10257 non-null  object
#  17  speaks                      10724 non-null  object
#  18  status                      10728 non-null  object
#  19  drink_level                 10728 non-null  object
#  20  drugs_level                 10728 non-null  int64
#  21  Edu_Type                    10728 non-null  object
#  22  Edu_Level                   10728 non-null  int64
#  23  kids_level                  10728 non-null  int64
#  24  dog_level                   10728 non-null  int64
#  25  cat_level                   10728 non-null  int64
#  26  smoke_level                 10728 non-null  int64
#  27  status_level                10728 non-null  int64
#  28  Diet_Type                   10728 non-null  object
#  29  religious_level_no_ath_agn  10728 non-null  int64
#  30  religious_level             10728 non-null  int64
#  31  agnosticism_level           1785 non-null   float64
#  32  atheism_level               1545 non-null   float64
#  33  hinduism_level              85 non-null     float64
#  34  islam_level                 35 non-null     float64
#  35  buddhism_level              395 non-null    float64
#  36  judaism_level               414 non-null    float64
#  37  christianity_level          1375 non-null   float64
#  38  catholicism_level           989 non-null    float64
#  39  religion_group              10728 non-null  object
#  40  income_group                10728 non-null  object
#  41  income_level                10728 non-null  int64
#  42  height_level                10728 non-null  int64
#  43  height_group                10728 non-null  object
#  44  pet_level                   7811 non-null   float64
#  45  inc                         10728 non-null  object
# dtypes: float64(10), int64(13), object(23)
# memory usage: 3.8+ MB

# %% [markdown]
# ## Income Visuals

# %%
# boxplot of religious group vs income
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_inc, x ="religion_group", y = "income", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Income by Religious Groups and Sex')
plt.savefig("OKCupidRelAgeSex.png")
plt.show()

# hindu men make most money

# %%
# boxplot of religious group vs income
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_inc, x ="religious_level", y = "income", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Income by Religious Level and Sex')
plt.ylim([20000, 65000])
plt.xlabel("Religious Level Scale Least to Greatest, 0:Unknown")
plt.savefig("OKCupidRelLevIncSex.png")
plt.show()

# most religious make least money

# %%
# boxplot of pet level vs income
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_inc, x ="pet_level", y = "income", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Religious Groups by Income and Sex')
plt.xlabel("Pet Level: From Haters (1) to Lovers (5)")
plt.ylim([20000, 72000])
plt.savefig("OKCupidPetAgeSex.png")
plt.show()

# men who hate or men who love pets make the most $$

# %%
# boxplot of dog level vs income
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_inc, x ="pet_level", y = "income", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Religious Groups by Income and Sex')
plt.xlabel("Pet Level: From Haters (1) to Lovers (5)")
plt.ylim([20000, 72000])
plt.savefig("OKCupidPetAgeSex.png")
plt.show()

# men who hate or men who love pets make the most $$

# %% [markdown]
# ## Height Visuals

# %%
#creating dataset with only people who answered height
df4_hgt = df3.copy()
df4_hgt["hgt"] = np.where(df4_hgt["height"]>=0, "Y", "N")
df4_hgt.drop(df4_hgt.loc[df4_hgt["hgt"]=="N"].index, inplace = True)

# %%
# boxplot of religious group vs height
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_hgt, x ="religion_group", y = "height", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Religious Groups by Height and Sex')
plt.ylim([60, 72])
plt.savefig("OKCupidRelHgtSex.png")
plt.show()

# no differences in height across religious groups

# %%
# boxplot of religious group vs height
pal = sns.color_palette("flare")
plt.figure(figsize = (15,5))
sns.barplot(data = df4_hgt, x ="income_group", y = "height", hue = "sex", ci = None, palette=np.array(pal[::4]), estimator = np.median)
plt.title('Income Groups by Height and Sex')
plt.ylim([60, 72])
plt.savefig("OKCupidIncGrpHgtSex.png")
plt.show()

# only very high earners stand out

# %%
#creating dataset with only people who answered height
df4_hgt = df3.copy()
df4_hgt["hgt"] = np.where(df4_hgt["height"]>=0, "Y", "N")
df4_hgt.drop(df4_hgt.loc[df4_hgt["hgt"]=="N"].index, inplace = True)

# %%
sns.barplot?

# %%
# boxplot of religious group vs age
pal = sns.color_palette("flare")

sns.barplot(x = df3["religion_group"], y = df3["income"], hue = df3["sex"], ci = None, palette=np.array(pal[::4]))
plt.title('Religious Groups by Income and Sex (Including Unknown)')

plt.savefig("OKCupidRelAgeSexAll.png")
plt.show()

# hindu men make more money than men of other religious groups??

# %%
# boxplot of religious group vs age
pal = sns.color_palette("flare")

sns.barplot(x = df3["religion_group"], y = df3["drink_level"], hue = df2["sex"], ci = None, palette=np.array(pal[::4]))
plt.title('Religious Groups by Income and Sex (Including Unknown)')

plt.savefig("OKCupidRelAgeSex.png")
plt.show()

# hindu men make more money than men of other religious groups??
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RVHU32~1\AppData\Local\Temp/ipykernel_11608/2786863184.py in <module>
#       2 pal = sns.color_palette("flare")
#       3
# ----> 4 sns.barplot(x = df3["religion_group"], y = df3["drink_level"], hue = df2["sex"], ci = None, palette=np.array(pal[::4]))
#       5 plt.title('Religious Groups by Income and Sex (Including Unknown)')
#       6
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1350     elif require_numeric and "numeric" not in (x_type, y_type):
#    1351         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1352         raise TypeError(err)
#    1353
#    1354     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %% [markdown]
# # Datasets in File
#
# #### df - original dataset
# ##### df3 - dataset without outliers and missing values, includes new pct_funded column
#
# ### Success and Fail Groups
# - df3_successful     108,800 rows
#      *mean campaign length: 32 days
#      *raise the highest median USD between 30 and 59 days
#
#      *nearly normal distribution for all categories
#
# - df3_failed         166,210 rows
#      *mean campaign length: 35 days
#      *skew high for all numerical variables
#
# - tech, design, games raise most money, whether successful or not
#
# ### Main Categories Groups
# - df3_food
# - df3_tech
# - df3_pub
# - df3_fash
# - df3_film
# - df3_photo
# - df3_comics
# - df3_design
# - df3_art
# - df3_journ
# - df3_music
# - df3_crafts
# - df3_dance
# - df3_thea
# - df3_games
#
#
# ### Backers Groups:
# - df3_backers_1: 0-4     68,698 rows
#      *best goal range for success:
#      *best length for success:
#
# - df3_backers_2: 5-19    51,506 rows
#      *best goal range for success:
#      *best length for success:
#
# - df3_backers_3: 20-59   54,341 rows
#      *best goal range for success:
#      *best length for success:
#
# - df3_backers_4: 60-99     23,892 rows
#      *best goal range for success:
#      *best length for success:
#
# - df3_backers_5: 100+      43,736 rows
#      *best goal range for success:
#      *best length for success:
#
#
# ### USD Pledged Groups:
# - df3_usd_pledged_1: 0-99               50,919 rows
# - df3_usd_pledged_2: 100-999            62,956 rows
# - df3_usd_pledged_3: 1,000-4,999        64,278 rows
# - df3_usd_pledged_4: 5,000-99,999       58,575 rows
# - df3_usd_pledged_5: 100,000-300,000    3,219 rows
#
#
# ### Pct Funded Groups:
# - df3_pct_funded_1: 0-49           128,844 rows
# - df3_pct_funded_2: 50-89            7,557 rows
# - df3_pct_funded_3: 90-99            3,925 rows
# - df3_pct_funded_4: 100-109         34,727 rows
# - df3_pct_funded_5: 110+            62,894 rows
#
#
# ### Length Days Groups:
# - df3_length_days_1: 0-14            14,455 rows
#      *SUCCESSFUL: 7,270 (50%)
#      *median usd pledged: 1,359
#      *best backers for success: 5-59
#      *best goal for success: 0-1,999
#
# - df3_length_days_2: 15-19          10,289 rows
#      *SUCCESSFUL: 5,418 (53%)
#      *mean usd pledged: 2,352
#      *best backers for success: 5-99
#      *best goal for success: 0-4,999
#
# - df3_length_days_3: 20-29          156,505 rows
#      *SUCCESSFUL: 60,670 (39%)
#      *mean usd pledged: 4,400
#      *best backers for success: 20+
#      *best goal for success: 0-14,999
#
# - df3_length_days_4: 30-59           92,244 rows
#      *SUCCESSFUL: 34,739 (38%)
#      *mean usd pledged: 5,596
#      *best backers for success: 20+
#      *best goal for success: 0-14,999
#
# - df3_length_days_5: 60-100           1,517 rows
#      *SUCCESSFUL: 703 (46%)
#      *mean usd pledged: 4,025
#      *best backers for success: 20-59
#      *best goal for success: 0-4,999
#
# - correlations betweeen 4 length_days_groups and goal inverted: -0.025, 0.045, 0.077, 0.019  (overall = 0.009)
# - NO MATTER THE CAMPAIGN LENGTH, MUSIC and THEATER ARE SUCCESSFUL
# - overall: as length increases, pct_funded decreases (r = -0.034)
#
#
#
# ### Goal Groups:
# - df3_goal_1: 0-1,999           76,693 rows
#      *SUCCESSFUL: 39,820 (52%)
#      *best backers for success: 5-59
#      *best length for success: 20-29 days
#
# - df3_goal_2: 2,000-4,999       67,004 rows
#      *SUCCESSFUL: 29,974 (45%)
#      *best backers for success: 20-99
#      *best length for success: 20-29 days
#
# - df3_goal_3: 5,000-14,999      68,732 rows
#      *SUCCESSFUL: 26,067 (38%)
#      *best backers for success: 100+
#      *best length for success: 20-59 days
#
# - df3_goal_4: 15,000-29,999     30,275 rows
#      *SUCCESSFUL: 8,512 (28%)
#      *best backers for success: 100+
#      *best length for success: 20-59 days
#
# - df3_goal_5: 30,000+           32,306 rows
#      *SUCCESSFUL: 4,427 (14%)
#      *best backers for success: 100+
#      *best length for success: 20-59 days

# %% [markdown]
# # Bins in File
# #### backers_group:
# ["0-9", "20-59", "60-99", "100-1500"]
# #### usd_pledged_group:
# ["0-99", "100-999", "1,000-4,999", "5,000-99,999", "100,000-300,000"]
# #### pct_funded_group:
# ["0-49", "50-89", "90-99", "100-109", "110+"]
# #### length_days_group:
# ["0-14", "15-29", "30-59", "60-100"]
# #### goal_group:
# ["0-1,999", "2,000-4,999", "5,000-14,999", "15,000-29,999", "30,000+"]

# %% [markdown]
# # Sub-Group Analysis

# %% [markdown]
# ## df3_backers_1 (0-19 backers) correlations
# - 1st: backers vs. state_binary = 0.429
# - 2nd: state_binary vs. length_days = -0.158
# - 3rd: length_days vs. goal = 0.081

# %% [markdown]
# ## df3_backers_2 (0-20 backers) correlations
# - 1st: backers vs. state_binary = 0.429
# - 2nd: state_binary vs. length_days = -0.158
# - 3rd: length_days vs. goal = 0.081

# %% [markdown]
# # # Art
#
# mean goal for successful art projects = $4,292
# median goal for successful art projects = $2,000
